# %% [markdown]
# ## Dataset creation
# In this pipeline we will build the final dataset that will be used for classificaiton
# - Balance the dataset on repos, datas and labels
# - Create issue msg (prompt)
# - Create issue embedding
# - Create training ad testing split

# %%
import os

os.chdir("..")
os.getcwd()

# %%
import pandas as pd
from datasets import load_dataset

ds = load_dataset("Eathus/cwe_view1003_raw_list", split="train")
cwe_1003_df = ds.to_pandas()

ds = load_dataset("Eathus/github-issues-references", split="train")
positive_df = ds.to_pandas()
display(positive_df.columns)
print(len(positive_df))

ds = load_dataset("Eathus/github-issues-negatives", split="train")
negative_df = ds.to_pandas()

positive_df.issue_owner_repo = positive_df.issue_owner_repo.map(tuple)
negative_df.issue_owner_repo = negative_df.issue_owner_repo.map(tuple)

negative_df = negative_df[
    ~negative_df.issue_github_id.isin(positive_df.issue_github_id)
]
# Out:
# train-00000-of-00001.parquet:   0%|          | 0.00/560k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/130 [00:00<?, ? examples/s]
# Index(['cve_id', 'cve_published', 'cve_descriptions', 'cve_metrics',
#        'cve_references', 'cve_configurations', 'cve_cwe_list',
#        'cve_primary_cwe', 'url', 'cve_tags', 'domain', 'issue_owner_repo',
#        'issue_body', 'issue_title', 'issue_comments_url',
#        'issue_comments_count', 'issue_created_at', 'issue_updated_at',
#        'issue_html_url', 'issue_github_id', 'issue_number'],
#       dtype='object')
# 1250

# %%
negative_df["issue_created_at"] = pd.to_datetime(
    negative_df["issue_created_at"], format="%Y-%m-%dT%H:%M:%SZ"
)
positive_df["issue_created_at"] = pd.to_datetime(
    positive_df["issue_created_at"], format="%Y-%m-%dT%H:%M:%SZ"
)

# %% [markdown]
# Let's reduce the time window of the issues in the negative dataset. The positive dataset it's made from references created between 01/01/2019 and 01/03/2025. It's so possible to thing that tracking issues created in that period are correctly tracked.
#
# In this way we want to reduce the chance of untracked issues that are not present in the references list

# %%
import datetime

start_date = datetime.datetime(2021, 1, 1)
end_date = datetime.datetime(2025, 3, 1)

negative_df = negative_df[
    (negative_df.issue_created_at > start_date)
    & (negative_df.issue_created_at < end_date)
]

# %%
print(len(negative_df))
print(len(negative_df.drop_duplicates('issue_github_id')))
# Out:
# 88335
# 88335

# %% [markdown]
# Let's also remove all the repos that have a too small presence in the negative dataset

# %%
vc = negative_df.issue_owner_repo.value_counts()
repos = vc[vc > 75].index

# %%
print(len(positive_df))
negative_df = negative_df[negative_df.issue_owner_repo.isin(repos)]
positive_df = positive_df[positive_df.issue_owner_repo.isin(repos)]
print(len(positive_df))
print(len(positive_df.drop_duplicates('issue_github_id')))
print(len(positive_df.drop_duplicates(['issue_github_id', 'cve_id'])))

duplicate_counts = positive_df['issue_github_id'].value_counts()
duplicate_counts = duplicate_counts[duplicate_counts > 1]
print("Duplicate counts per issue_github_id:")
display(duplicate_counts)

duplicate_counts = positive_df[['issue_github_id', 'cve_id']].value_counts()
duplicate_counts = duplicate_counts[duplicate_counts > 1]
print("Duplicate counts per issue_github_id:")

display(duplicate_counts)
# Out:
# 903
# 903
# 866
# 899
# Duplicate counts per issue_github_id:
# issue_github_id
# 549961224     13
# 541977765      8
# 547887727      7
# 544834443      7
# 503095531      2
# 1646878719     2
# 1998710063     2
# 1668648319     2
# 2057585750     2
# 1648637134     2
# Name: count, dtype: int64
# Duplicate counts per issue_github_id:
# issue_github_id  cve_id
# 1998710063       CVE-2024-8946     2
# 541977765        CVE-2019-20009    2
# 2057585750       CVE-2024-8947     2
# 503095531        CVE-2020-25663    2
# Name: count, dtype: int64

# %%
inconsistent_mask = (
    positive_df
    .groupby('issue_github_id')['cve_primary_cwe']
    .transform(lambda x: x.nunique() > 1)  # True if 'primary_cwe' varies in the group
)
display(list(positive_df
    .groupby('issue_github_id')['cve_primary_cwe']))

# Step 2: Get the inconsistent duplicates (for inspection)
inconsistent_duplicates = positive_df[inconsistent_mask].sort_values('issue_github_id')

# Step 3: Drop duplicates ONLY where 'primary_cwe' is inconsistent
# (Keep first occurrence where duplicates have the same 'primary_cwe')
consistent_deduped = (
    positive_df
    .sort_values('cve_primary_cwe')  # Optional: Sort to prioritize certain CWE values
    .drop_duplicates(
        subset='issue_github_id',
        keep='first'
    )
)
print(f"Original length: {len(positive_df)}")
print(f"After dropping inconsistent duplicates: {len(consistent_deduped)}")

strict_deduped = positive_df[~inconsistent_mask]
print(len(strict_deduped))
# Out:
# [(128365381,
#   143    125
#   Name: cve_primary_cwe, dtype: object),
#  (128365398,
#   144    125
#   Name: cve_primary_cwe, dtype: object),
#  (151080998,
#   488    335
#   Name: cve_primary_cwe, dtype: object),
#  (248590588,
#   39    400
#   Name: cve_primary_cwe, dtype: object),
#  (249233709,
#   38    400
#   Name: cve_primary_cwe, dtype: object),
#  (257947117,
#   1041    476
#   Name: cve_primary_cwe, dtype: object),
#  (337760000,
#   242    674
#   Name: cve_primary_cwe, dtype: object),
#  (351251936,
#   71    787
#   Name: cve_primary_cwe, dtype: object),
#  (351978078,
#   103    400
#   Name: cve_primary_cwe, dtype: object),
#  (390618242,
#   7    787
#   Name: cve_primary_cwe, dtype: object),
#  (391351147,
#   81    476
#   Name: cve_primary_cwe, dtype: object),
#  (391352422,
#   82    125
#   Name: cve_primary_cwe, dtype: object),
#  (391610142,
#   627    770
#   Name: cve_primary_cwe, dtype: object),
#  (391773951,
#   83    401
#   Name: cve_primary_cwe, dtype: object),
#  (393636374,
#   8    119
#   Name: cve_primary_cwe, dtype: object),
#  (393636571,
#   9    119
#   Name: cve_primary_cwe, dtype: object),
#  (393637600,
#   10    787
#   Name: cve_primary_cwe, dtype: object),
#  (394998583,
#   0    770
#   Name: cve_primary_cwe, dtype: object),
#  (395069674,
#   13    617
#   Name: cve_primary_cwe, dtype: object),
#  (395072870,
#   14    770
#   Name: cve_primary_cwe, dtype: object),
#  (395075442,
#   15    125
#   Name: cve_primary_cwe, dtype: object),
#  (395158669,
#   20    787
#   Name: cve_primary_cwe, dtype: object),
#  (395159602,
#   19    476
#   Name: cve_primary_cwe, dtype: object),
#  (397925621,
#   1    401
#   Name: cve_primary_cwe, dtype: object),
#  (400085839,
#   22    401
#   Name: cve_primary_cwe, dtype: object),
#  (400092278,
#   3    401
#   Name: cve_primary_cwe, dtype: object),
#  (400102085,
#   4    401
#   Name: cve_primary_cwe, dtype: object),
#  (400133504,
#   6    401
#   Name: cve_primary_cwe, dtype: object),
#  (400178531,
#   12    770
#   Name: cve_primary_cwe, dtype: object),
#  (400178750,
#   11    770
#   Name: cve_primary_cwe, dtype: object),
#  (400226040,
#   5    401
#   Name: cve_primary_cwe, dtype: object),
#  (403042062,
#   2    770
#   Name: cve_primary_cwe, dtype: object),
#  (404151105,
#   16    125
#   Name: cve_primary_cwe, dtype: object),
#  (405641344,
#   18    476
#   Name: cve_primary_cwe, dtype: object),
#  (406625350,
#   34    400
#   Name: cve_primary_cwe, dtype: object),
#  (407559605,
#   17    476
#   Name: cve_primary_cwe, dtype: object),
#  (409106668,
#   29    787
#   Name: cve_primary_cwe, dtype: object),
#  (409659238,
#   30    787
#   Name: cve_primary_cwe, dtype: object),
#  (409715577,
#   31    787
#   Name: cve_primary_cwe, dtype: object),
#  (414272146,
#   27    770
#   Name: cve_primary_cwe, dtype: object),
#  (415495144,
#   85    125
#   Name: cve_primary_cwe, dtype: object),
#  (415682606,
#   21    787
#   Name: cve_primary_cwe, dtype: object),
#  (416830460,
#   28    125
#   Name: cve_primary_cwe, dtype: object),
#  (419920036,
#   23    787
#   Name: cve_primary_cwe, dtype: object),
#  (423558712,
#   41    476
#   Name: cve_primary_cwe, dtype: object),
#  (423586613,
#   42    401
#   Name: cve_primary_cwe, dtype: object),
#  (423590022,
#   44    665
#   Name: cve_primary_cwe, dtype: object),
#  (423592141,
#   45    665
#   Name: cve_primary_cwe, dtype: object),
#  (423598777,
#   43    401
#   Name: cve_primary_cwe, dtype: object),
#  (423694012,
#   46    665
#   Name: cve_primary_cwe, dtype: object),
#  (424144480,
#   24    787
#   Name: cve_primary_cwe, dtype: object),
#  (424808689,
#   87    401
#   Name: cve_primary_cwe, dtype: object),
#  (425832104,
#   86    401
#   Name: cve_primary_cwe, dtype: object),
#  (426560687,
#   26    125
#   Name: cve_primary_cwe, dtype: object),
#  (426565379,
#   25    401
#   Name: cve_primary_cwe, dtype: object),
#  (430236223,
#   37    125
#   Name: cve_primary_cwe, dtype: object),
#  (431795900,
#   88    401
#   Name: cve_primary_cwe, dtype: object),
#  (432941385,
#   35    369
#   Name: cve_primary_cwe, dtype: object),
#  (433964918,
#   33    732
#   Name: cve_primary_cwe, dtype: object),
#  (434607141,
#   72    369
#   Name: cve_primary_cwe, dtype: object),
#  (434967981,
#   32    212
#   Name: cve_primary_cwe, dtype: object),
#  (435396971,
#   73    125
#   Name: cve_primary_cwe, dtype: object),
#  (437680361,
#   290    770
#   Name: cve_primary_cwe, dtype: object),
#  (437915586,
#   74    416
#   Name: cve_primary_cwe, dtype: object),
#  (437941914,
#   36    125
#   Name: cve_primary_cwe, dtype: object),
#  (438012692,
#   89    401
#   Name: cve_primary_cwe, dtype: object),
#  (438013444,
#   90    401
#   Name: cve_primary_cwe, dtype: object),
#  (438043984,
#   75    125
#   Name: cve_primary_cwe, dtype: object),
#  (438133289,
#   105    125
#   Name: cve_primary_cwe, dtype: object),
#  (438134907,
#   104    787
#   Name: cve_primary_cwe, dtype: object),
#  (440418682,
#   523    89
#   Name: cve_primary_cwe, dtype: object),
#  (440625122,
#   524    89
#   Name: cve_primary_cwe, dtype: object),
#  (441151429,
#   525    89
#   Name: cve_primary_cwe, dtype: object),
#  (441604948,
#   526    89
#   Name: cve_primary_cwe, dtype: object),
#  (443731009,
#   70    476
#   Name: cve_primary_cwe, dtype: object),
#  (448195676,
#   51    476
#   Name: cve_primary_cwe, dtype: object),
#  (448700419,
#   40    476
#   Name: cve_primary_cwe, dtype: object),
#  (449103722,
#   243    674
#   Name: cve_primary_cwe, dtype: object),
#  (449105468,
#   244    674
#   Name: cve_primary_cwe, dtype: object),
#  (451854770,
#   69    125
#   Name: cve_primary_cwe, dtype: object),
#  (454202041,
#   58    401
#   Name: cve_primary_cwe, dtype: object),
#  (454242285,
#   57    787
#   Name: cve_primary_cwe, dtype: object),
#  (454462914,
#   67    125
#   Name: cve_primary_cwe, dtype: object),
#  (454487713,
#   59    401
#   Name: cve_primary_cwe, dtype: object),
#  (456713579,
#   64    787
#   Name: cve_primary_cwe, dtype: object),
#  (456730033,
#   60    125
#   Name: cve_primary_cwe, dtype: object),
#  (457391875,
#   48    908
#   Name: cve_primary_cwe, dtype: object),
#  (457401228,
#   47    401
#   Name: cve_primary_cwe, dtype: object),
#  (457404400,
#   50    401
#   Name: cve_primary_cwe, dtype: object),
#  (457432764,
#   49    190
#   Name: cve_primary_cwe, dtype: object),
#  (457598033,
#   61    125
#   Name: cve_primary_cwe, dtype: object),
#  (457603906,
#   53    401
#   Name: cve_primary_cwe, dtype: object),
#  (459023037,
#   52    125
#   Name: cve_primary_cwe, dtype: object),
#  (459024141,
#   54    125
#   Name: cve_primary_cwe, dtype: object),
#  (459025122,
#   56    125
#   Name: cve_primary_cwe, dtype: object),
#  (459025805,
#   55    787
#   Name: cve_primary_cwe, dtype: object),
#  (459035202,
#   62    787
#   Name: cve_primary_cwe, dtype: object),
#  (459421750,
#   63    787
#   Name: cve_primary_cwe, dtype: object),
#  (459551673,
#   65    401
#   Name: cve_primary_cwe, dtype: object),
#  (462846647,
#   66    401
#   Name: cve_primary_cwe, dtype: object),
#  (464559871,
#   293    125
#   Name: cve_primary_cwe, dtype: object),
#  (464790539,
#   273    476
#   Name: cve_primary_cwe, dtype: object),
#  (464791707,
#   148    125
#   Name: cve_primary_cwe, dtype: object),
#  (464797091,
#   270    125
#   Name: cve_primary_cwe, dtype: object),
#  (464797129,
#   271    125
#   Name: cve_primary_cwe, dtype: object),
#  (464797889,
#   272    125
#   Name: cve_primary_cwe, dtype: object),
#  (464799415,
#   149    125
#   Name: cve_primary_cwe, dtype: object),
#  (464799448,
#   147    416
#   Name: cve_primary_cwe, dtype: object),
#  (464799484,
#   150    763
#   Name: cve_primary_cwe, dtype: object),
#  (464800676,
#   151    763
#   Name: cve_primary_cwe, dtype: object),
#  (464908207,
#   68    369
#   Name: cve_primary_cwe, dtype: object),
#  (465232934,
#   294    125
#   Name: cve_primary_cwe, dtype: object),
#  (469671879,
#   99    416
#   Name: cve_primary_cwe, dtype: object),
#  (470163532,
#   284    787
#   Name: cve_primary_cwe, dtype: object),
#  (476838684,
#   77    863
#   Name: cve_primary_cwe, dtype: object),
#  (476838777,
#   79    22
#   Name: cve_primary_cwe, dtype: object),
#  (477418481,
#   78    862
#   Name: cve_primary_cwe, dtype: object),
#  (478213865,
#   80    532
#   Name: cve_primary_cwe, dtype: object),
#  (478968882,
#   266    120
#   Name: cve_primary_cwe, dtype: object),
#  (478997749,
#   267    787
#   Name: cve_primary_cwe, dtype: object),
#  (479003776,
#   264    476
#   Name: cve_primary_cwe, dtype: object),
#  (479014683,
#   265    476
#   Name: cve_primary_cwe, dtype: object),
#  (481961506,
#   84    476
#   Name: cve_primary_cwe, dtype: object),
#  (496866994,
#   97    125
#   Name: cve_primary_cwe, dtype: object),
#  (496867352,
#   98    125
#   Name: cve_primary_cwe, dtype: object),
#  (499548171,
#   100    776
#   Name: cve_primary_cwe, dtype: object),
#  (499946487,
#   93    476
#   Name: cve_primary_cwe, dtype: object),
#  (499963127,
#   96    476
#   Name: cve_primary_cwe, dtype: object),
#  (500109805,
#   94    476
#   Name: cve_primary_cwe, dtype: object),
#  (500387590,
#   95    476
#   Name: cve_primary_cwe, dtype: object),
#  (503095531,
#   179    416
#   180    416
#   Name: cve_primary_cwe, dtype: object),
#  (513392746,
#   119    787
#   Name: cve_primary_cwe, dtype: object),
#  (513400465,
#   117    401
#   Name: cve_primary_cwe, dtype: object),
#  (520392881,
#   120    787
#   Name: cve_primary_cwe, dtype: object),
#  (520393299,
#   128    763
#   Name: cve_primary_cwe, dtype: object),
#  (520393655,
#   127    416
#   Name: cve_primary_cwe, dtype: object),
#  (520393923,
#   125    476
#   Name: cve_primary_cwe, dtype: object),
#  (520394250,
#   124    476
#   Name: cve_primary_cwe, dtype: object),
#  (520394510,
#   122    476
#   Name: cve_primary_cwe, dtype: object),
#  (520394786,
#   126    416
#   Name: cve_primary_cwe, dtype: object),
#  (520394957,
#   118    787
#   Name: cve_primary_cwe, dtype: object),
#  (520395160,
#   121    476
#   Name: cve_primary_cwe, dtype: object),
#  (520403921,
#   129    401
#   Name: cve_primary_cwe, dtype: object),
#  (520405629,
#   123    476
#   Name: cve_primary_cwe, dtype: object),
#  (521931348,
#   369    787
#   Name: cve_primary_cwe, dtype: object),
#  (521942076,
#   368    787
#   Name: cve_primary_cwe, dtype: object),
#  (521946411,
#   365    401
#   Name: cve_primary_cwe, dtype: object),
#  (521966021,
#   367    787
#   Name: cve_primary_cwe, dtype: object),
#  (521967985,
#   370    401
#   Name: cve_primary_cwe, dtype: object),
#  (522006717,
#   366    476
#   Name: cve_primary_cwe, dtype: object),
#  (522010451,
#   130    787
#   Name: cve_primary_cwe, dtype: object),
#  (522468661,
#   102    20
#   Name: cve_primary_cwe, dtype: object),
#  (529151827,
#   106    416
#   Name: cve_primary_cwe, dtype: object),
#  (532323568,
#   101    601
#   Name: cve_primary_cwe, dtype: object),
#  (534780352,
#   115    416
#   Name: cve_primary_cwe, dtype: object),
#  (534783741,
#   116    476
#   Name: cve_primary_cwe, dtype: object),
#  (541977765,
#   107    770
#   108    770
#   109    416
#   110    125
#   111    770
#   112    770
#   113    415
#   114    770
#   Name: cve_primary_cwe, dtype: object),
#  (544098538,
#   164    476
#   Name: cve_primary_cwe, dtype: object),
#  (544416874,
#   140    476
#   Name: cve_primary_cwe, dtype: object),
#  (544417280,
#   141    476
#   Name: cve_primary_cwe, dtype: object),
#  (544834443,
#   131    125
#   132    770
#   133    476
#   134    125
#   135    125
#   136    125
#   137    476
#   Name: cve_primary_cwe, dtype: object),
#  (546016991,
#   139    476
#   Name: cve_primary_cwe, dtype: object),
#  (546033507,
#   138    125
#   Name: cve_primary_cwe, dtype: object),
#  (547887727,
#   220    787
#   221    787
#   222    476
#   223    787
#   224    476
#   225    787
#   226    787
#   Name: cve_primary_cwe, dtype: object),
#  (548674750,
#   227    787
#   Name: cve_primary_cwe, dtype: object),
#  (549536132,
#   165    476
#   Name: cve_primary_cwe, dtype: object),
#  (549961224,
#   228    787
#   229    787
#   230    787
#   231    476
#   232    476
#   233    787
#   234    787
#   235    401
#   236    787
#   237    787
#   238    787
#   239    787
#   240    787
#   Name: cve_primary_cwe, dtype: object),
#  (550751408,
#   166    476
#   Name: cve_primary_cwe, dtype: object),
#  (550758758,
#   167    476
#   Name: cve_primary_cwe, dtype: object),
#  (552310420,
#   145    79
#   Name: cve_primary_cwe, dtype: object),
#  (559146411,
#   142    59
#   Name: cve_primary_cwe, dtype: object),
#  (562020033,
#   411    476
#   Name: cve_primary_cwe, dtype: object),
#  (563700554,
#   268    79
#   Name: cve_primary_cwe, dtype: object),
#  (563727063,
#   269    79
#   Name: cve_primary_cwe, dtype: object),
#  (573596583,
#   275    787
#   Name: cve_primary_cwe, dtype: object),
#  (573599771,
#   274    476
#   Name: cve_primary_cwe, dtype: object),
#  (573994956,
#   916    787
#   Name: cve_primary_cwe, dtype: object),
#  (574875269,
#   146    125
#   Name: cve_primary_cwe, dtype: object),
#  (586428637,
#   153    770
#   Name: cve_primary_cwe, dtype: object),
#  (586429123,
#   154    770
#   Name: cve_primary_cwe, dtype: object),
#  (586943552,
#   152    79
#   Name: cve_primary_cwe, dtype: object),
#  (587134103,
#   156    416
#   Name: cve_primary_cwe, dtype: object),
#  (588652998,
#   155    1050
#   Name: cve_primary_cwe, dtype: object),
#  (599474018,
#   174    787
#   Name: cve_primary_cwe, dtype: object),
#  (601663070,
#   157    125
#   Name: cve_primary_cwe, dtype: object),
#  (601663990,
#   158    125
#   Name: cve_primary_cwe, dtype: object),
#  (616789021,
#   360    787
#   Name: cve_primary_cwe, dtype: object),
#  (616861182,
#   359    787
#   Name: cve_primary_cwe, dtype: object),
#  (617067875,
#   361    787
#   Name: cve_primary_cwe, dtype: object),
#  (619406496,
#   288    787
#   Name: cve_primary_cwe, dtype: object),
#  (619408633,
#   289    787
#   Name: cve_primary_cwe, dtype: object),
#  (619450232,
#   286    476
#   Name: cve_primary_cwe, dtype: object),
#  (619451101,
#   287    787
#   Name: cve_primary_cwe, dtype: object),
#  (619458135,
#   285    476
#   Name: cve_primary_cwe, dtype: object),
#  (619599547,
#   245    416
#   Name: cve_primary_cwe, dtype: object),
#  (619604019,
#   246    787
#   Name: cve_primary_cwe, dtype: object),
#  (619915696,
#   247    787
#   Name: cve_primary_cwe, dtype: object),
#  (623613918,
#   160    400
#   Name: cve_primary_cwe, dtype: object),
#  (623709607,
#   159    617
#   Name: cve_primary_cwe, dtype: object),
#  (625930295,
#   163    125
#   Name: cve_primary_cwe, dtype: object),
#  (625973443,
#   161    200
#   Name: cve_primary_cwe, dtype: object),
#  (626636248,
#   162    918
#   Name: cve_primary_cwe, dtype: object),
#  (627968037,
#   248    617
#   Name: cve_primary_cwe, dtype: object),
#  (627972924,
#   249    617
#   Name: cve_primary_cwe, dtype: object),
#  (628117790,
#   250    617
#   Name: cve_primary_cwe, dtype: object),
#  (628120323,
#   251    617
#   Name: cve_primary_cwe, dtype: object),
#  (628134730,
#   253    617
#   Name: cve_primary_cwe, dtype: object),
#  (628139379,
#   252    617
#   Name: cve_primary_cwe, dtype: object),
#  (628146890,
#   254    617
#   Name: cve_primary_cwe, dtype: object),
#  (629668362,
#   255    617
#   Name: cve_primary_cwe, dtype: object),
#  (629674784,
#   256    617
#   Name: cve_primary_cwe, dtype: object),
#  (632478665,
#   258    617
#   Name: cve_primary_cwe, dtype: object),
#  (632483470,
#   257    787
#   Name: cve_primary_cwe, dtype: object),
#  (633297568,
#   259    787
#   Name: cve_primary_cwe, dtype: object),
#  (642156921,
#   170    420
#   Name: cve_primary_cwe, dtype: object),
#  (651142365,
#   171    125
#   Name: cve_primary_cwe, dtype: object),
#  (651247064,
#   172    787
#   Name: cve_primary_cwe, dtype: object),
#  (653456402,
#   168    601
#   Name: cve_primary_cwe, dtype: object),
#  (656058152,
#   169    400
#   Name: cve_primary_cwe, dtype: object),
#  (660117543,
#   241    787
#   Name: cve_primary_cwe, dtype: object),
#  (665599573,
#   263    416
#   Name: cve_primary_cwe, dtype: object),
#  (666814219,
#   921    476
#   Name: cve_primary_cwe, dtype: object),
#  (668541948,
#   173    79
#   Name: cve_primary_cwe, dtype: object),
#  (669581382,
#   319    476
#   Name: cve_primary_cwe, dtype: object),
#  (669586008,
#   321    787
#   Name: cve_primary_cwe, dtype: object),
#  (669753229,
#   318    787
#   Name: cve_primary_cwe, dtype: object),
#  (670451905,
#   212    476
#   Name: cve_primary_cwe, dtype: object),
#  (670848928,
#   322    415
#   Name: cve_primary_cwe, dtype: object),
#  (671412127,
#   323    787
#   Name: cve_primary_cwe, dtype: object),
#  (671508299,
#   320    787
#   Name: cve_primary_cwe, dtype: object),
#  (672111174,
#   317    476
#   Name: cve_primary_cwe, dtype: object),
#  (674698771,
#   216    125
#   Name: cve_primary_cwe, dtype: object),
#  (674711009,
#   215    476
#   Name: cve_primary_cwe, dtype: object),
#  (674723890,
#   218    476
#   Name: cve_primary_cwe, dtype: object),
#  (674751358,
#   217    125
#   Name: cve_primary_cwe, dtype: object),
#  (674752234,
#   213    125
#   Name: cve_primary_cwe, dtype: object),
#  (675069002,
#   214    125
#   Name: cve_primary_cwe, dtype: object),
#  (678118496,
#   314    476
#   Name: cve_primary_cwe, dtype: object),
#  (679475781,
#   316    787
#   Name: cve_primary_cwe, dtype: object),
#  (683904034,
#   312    120
#   Name: cve_primary_cwe, dtype: object),
#  (683924702,
#   922    352
#   Name: cve_primary_cwe, dtype: object),
#  (684668891,
#   499    787
#   Name: cve_primary_cwe, dtype: object),
#  (684675767,
#   500    787
#   Name: cve_primary_cwe, dtype: object),
#  (685372287,
#   501    787
#   Name: cve_primary_cwe, dtype: object),
#  (685379611,
#   502    125
#   Name: cve_primary_cwe, dtype: object),
#  (685385426,
#   503    125
#   Name: cve_primary_cwe, dtype: object),
#  (693262344,
#   315    476
#   Name: cve_primary_cwe, dtype: object),
#  (693270293,
#   313    787
#   Name: cve_primary_cwe, dtype: object),
#  (708663828,
#   498    476
#   Name: cve_primary_cwe, dtype: object),
#  (710666807,
#   181    125
#   Name: cve_primary_cwe, dtype: object),
#  (722704051,
#   175    532
#   Name: cve_primary_cwe, dtype: object),
#  (722705294,
#   176    532
#   Name: cve_primary_cwe, dtype: object),
#  (722706304,
#   177    532
#   Name: cve_primary_cwe, dtype: object),
#  (722707368,
#   178    532
#   Name: cve_primary_cwe, dtype: object),
#  (728661432,
#   924    74
#   Name: cve_primary_cwe, dtype: object),
#  (732315548,
#   925    79
#   Name: cve_primary_cwe, dtype: object),
#  (745495627,
#   182    79
#   Name: cve_primary_cwe, dtype: object),
#  (753571210,
#   933    401
#   Name: cve_primary_cwe, dtype: object),
#  (757368290,
#   185    283
#   Name: cve_primary_cwe, dtype: object),
#  (767517846,
#   210    476
#   Name: cve_primary_cwe, dtype: object),
#  (767519058,
#   211    476
#   Name: cve_primary_cwe, dtype: object),
#  (767520741,
#   209    416
#   Name: cve_primary_cwe, dtype: object),
#  (767522021,
#   208    787
#   Name: cve_primary_cwe, dtype: object),
#  (777469465,
#   262    754
#   Name: cve_primary_cwe, dtype: object),
#  (783354413,
#   261    787
#   Name: cve_primary_cwe, dtype: object),
#  (783371449,
#   260    416
#   Name: cve_primary_cwe, dtype: object),
#  (798961516,
#   186    369
#   Name: cve_primary_cwe, dtype: object),
#  (818783675,
#   191    89
#   Name: cve_primary_cwe, dtype: object),
#  (820916089,
#   372    476
#   Name: cve_primary_cwe, dtype: object),
#  (821736833,
#   373    787
#   Name: cve_primary_cwe, dtype: object),
#  (828149421,
#   291    372
#   Name: cve_primary_cwe, dtype: object),
#  (828599474,
#   192    476
#   Name: cve_primary_cwe, dtype: object),
#  (828921799,
#   193    787
#   Name: cve_primary_cwe, dtype: object),
#  (829695046,
#   195    401
#   Name: cve_primary_cwe, dtype: object),
#  (829813689,
#   197    476
#   Name: cve_primary_cwe, dtype: object),
#  (842980682,
#   203    476
#   Name: cve_primary_cwe, dtype: object),
#  (842986600,
#   206    190
#   Name: cve_primary_cwe, dtype: object),
#  (843003944,
#   202    190
#   Name: cve_primary_cwe, dtype: object),
#  (843020967,
#   205    787
#   Name: cve_primary_cwe, dtype: object),
#  (843060662,
#   204    787
#   Name: cve_primary_cwe, dtype: object),
#  (849144670,
#   207    476
#   Name: cve_primary_cwe, dtype: object),
#  (853037318,
#   194    120
#   Name: cve_primary_cwe, dtype: object),
#  (853037887,
#   196    476
#   Name: cve_primary_cwe, dtype: object),
#  (853054686,
#   784    401
#   Name: cve_primary_cwe, dtype: object),
#  (853144448,
#   198    476
#   Name: cve_primary_cwe, dtype: object),
#  (853145443,
#   199    476
#   Name: cve_primary_cwe, dtype: object),
#  (854055228,
#   200    119
#   Name: cve_primary_cwe, dtype: object),
#  (854055702,
#   201    476
#   Name: cve_primary_cwe, dtype: object),
#  (857040605,
#   609    401
#   Name: cve_primary_cwe, dtype: object),
#  (864665765,
#   302    476
#   Name: cve_primary_cwe, dtype: object),
#  (865638887,
#   300    476
#   Name: cve_primary_cwe, dtype: object),
#  (865639263,
#   303    476
#   Name: cve_primary_cwe, dtype: object),
#  (867719689,
#   668    400
#   Name: cve_primary_cwe, dtype: object),
#  (868051410,
#   489    367
#   Name: cve_primary_cwe, dtype: object),
#  (871724292,
#   299    787
#   Name: cve_primary_cwe, dtype: object),
#  (871726037,
#   301    787
#   Name: cve_primary_cwe, dtype: object),
#  (871728422,
#   307    476
#   Name: cve_primary_cwe, dtype: object),
#  (871729530,
#   308    476
#   Name: cve_primary_cwe, dtype: object),
#  (872138105,
#   281    476
#   Name: cve_primary_cwe, dtype: object),
#  (872144270,
#   280    476
#   Name: cve_primary_cwe, dtype: object),
#  (872155736,
#   283    476
#   Name: cve_primary_cwe, dtype: object),
#  (872168928,
#   282    120
#   Name: cve_primary_cwe, dtype: object),
#  (873925774,
#   406    150
#   Name: cve_primary_cwe, dtype: object),
#  (880291127,
#   304    787
#   Name: cve_primary_cwe, dtype: object),
#  (880294671,
#   309    401
#   Name: cve_primary_cwe, dtype: object),
#  (880295889,
#   305    401
#   Name: cve_primary_cwe, dtype: object),
#  (880296904,
#   311    401
#   Name: cve_primary_cwe, dtype: object),
#  (880298140,
#   306    401
#   Name: cve_primary_cwe, dtype: object),
#  (880299345,
#   310    401
#   Name: cve_primary_cwe, dtype: object),
#  (890930565,
#   219    89
#   Name: cve_primary_cwe, dtype: object),
#  (894695650,
#   292    601
#   Name: cve_primary_cwe, dtype: object),
#  (895156817,
#   572    787
#   Name: cve_primary_cwe, dtype: object),
#  (895159181,
#   571    401
#   Name: cve_primary_cwe, dtype: object),
#  (895160290,
#   575    476
#   Name: cve_primary_cwe, dtype: object),
#  (895161153,
#   582    476
#   Name: cve_primary_cwe, dtype: object),
#  (895161871,
#   573    476
#   Name: cve_primary_cwe, dtype: object),
#  (895162768,
#   580    476
#   Name: cve_primary_cwe, dtype: object),
#  (895163896,
#   574    476
#   Name: cve_primary_cwe, dtype: object),
#  (895164624,
#   577    476
#   Name: cve_primary_cwe, dtype: object),
#  (895165377,
#   576    787
#   Name: cve_primary_cwe, dtype: object),
#  (895166227,
#   579    476
#   Name: cve_primary_cwe, dtype: object),
#  (895166975,
#   578    476
#   Name: cve_primary_cwe, dtype: object),
#  (895167796,
#   581    787
#   Name: cve_primary_cwe, dtype: object),
#  (913233568,
#   532    787
#   Name: cve_primary_cwe, dtype: object),
#  (913238141,
#   531    787
#   Name: cve_primary_cwe, dtype: object),
#  (917334988,
#   276    476
#   Name: cve_primary_cwe, dtype: object),
#  (917392735,
#   277    476
#   Name: cve_primary_cwe, dtype: object),
#  (933378748,
#   715    787
#   Name: cve_primary_cwe, dtype: object),
#  (936163558,
#   412    787
#   Name: cve_primary_cwe, dtype: object),
#  (937046365,
#   413    787
#   Name: cve_primary_cwe, dtype: object),
#  (937474838,
#   278    787
#   Name: cve_primary_cwe, dtype: object),
#  (938434438,
#   414    787
#   Name: cve_primary_cwe, dtype: object),
#  (944001066,
#   357    610
#   Name: cve_primary_cwe, dtype: object),
#  (945118917,
#   718    732
#   Name: cve_primary_cwe, dtype: object),
#  (945135797,
#   719    732
#   Name: cve_primary_cwe, dtype: object),
#  (971526752,
#   547    835
#   Name: cve_primary_cwe, dtype: object),
#  (974213413,
#   565    770
#   Name: cve_primary_cwe, dtype: object),
#  (975274297,
#   566    908
#   Name: cve_primary_cwe, dtype: object),
#  (976075255,
#   932    369
#   Name: cve_primary_cwe, dtype: object),
#  (977647480,
#   564    125
#   Name: cve_primary_cwe, dtype: object),
#  (977665470,
#   553    787
#   Name: cve_primary_cwe, dtype: object),
#  (977668295,
#   552    416
#   Name: cve_primary_cwe, dtype: object),
#  (977781016,
#   415    476
#   Name: cve_primary_cwe, dtype: object),
#  (977822133,
#   420    416
#   Name: cve_primary_cwe, dtype: object),
#  (978627371,
#   568    476
#   Name: cve_primary_cwe, dtype: object),
#  (978628921,
#   562    770
#   Name: cve_primary_cwe, dtype: object),
#  (978737969,
#   422    415
#   Name: cve_primary_cwe, dtype: object),
#  (978778065,
#   426    415
#   Name: cve_primary_cwe, dtype: object),
#  (978799447,
#   417    476
#   Name: cve_primary_cwe, dtype: object),
#  (978804732,
#   425    415
#   Name: cve_primary_cwe, dtype: object),
#  (979828664,
#   567    770
#   Name: cve_primary_cwe, dtype: object),
#  (980052585,
#   424    415
#   Name: cve_primary_cwe, dtype: object),
#  (980128523,
#   427    415
#   Name: cve_primary_cwe, dtype: object),
#  (980141709,
#   418    476
#   Name: cve_primary_cwe, dtype: object),
#  (981033321,
#   423    415
#   Name: cve_primary_cwe, dtype: object),
#  (981044009,
#   421    120
#   Name: cve_primary_cwe, dtype: object),
#  (981936669,
#   510    125
#   Name: cve_primary_cwe, dtype: object),
#  (982002210,
#   374    89
#   Name: cve_primary_cwe, dtype: object),
#  (982104453,
#   534    89
#   Name: cve_primary_cwe, dtype: object),
#  (982108403,
#   416    697
#   Name: cve_primary_cwe, dtype: object),
#  (982110519,
#   419    476
#   Name: cve_primary_cwe, dtype: object),
#  (983792109,
#   429    476
#   Name: cve_primary_cwe, dtype: object),
#  (984701234,
#   428    476
#   Name: cve_primary_cwe, dtype: object),
#  (984803968,
#   569    476
#   Name: cve_primary_cwe, dtype: object),
#  (985625732,
#   356    610
#   Name: cve_primary_cwe, dtype: object),
#  (988691714,
#   550    79
#   Name: cve_primary_cwe, dtype: object),
#  (989561835,
#   375    79
#   Name: cve_primary_cwe, dtype: object),
#  (989818036,
#   563    787
#   Name: cve_primary_cwe, dtype: object),
#  (990103636,
#   363    787
#   Name: cve_primary_cwe, dtype: object),
#  (990148297,
#   551    787
#   Name: cve_primary_cwe, dtype: object),
#  (990150575,
#   362    787
#   Name: cve_primary_cwe, dtype: object),
#  (990155594,
#   364    787
#   Name: cve_primary_cwe, dtype: object),
#  (995325596,
#   358    552
#   Name: cve_primary_cwe, dtype: object),
#  (1005422113,
#   509    674
#   Name: cve_primary_cwe, dtype: object),
#  (1007794199,
#   519    401
#   Name: cve_primary_cwe, dtype: object),
#  (1024703352,
#   528    120
#   Name: cve_primary_cwe, dtype: object),
#  (1046416827,
#   371    416
#   Name: cve_primary_cwe, dtype: object),
#  (1067002316,
#   504    79
#   Name: cve_primary_cwe, dtype: object),
#  (1067981255,
#   400    770
#   Name: cve_primary_cwe, dtype: object),
#  (1067997303,
#   399    770
#   Name: cve_primary_cwe, dtype: object),
#  (1073083583,
#   451    617
#   Name: cve_primary_cwe, dtype: object),
#  (1073189379,
#   450    787
#   Name: cve_primary_cwe, dtype: object),
#  (1073404012,
#   455    787
#   Name: cve_primary_cwe, dtype: object),
#  (1075250208,
#   452    617
#   Name: cve_primary_cwe, dtype: object),
#  (1075325382,
#   465    119
#   Name: cve_primary_cwe, dtype: object),
#  (1075367669,
#   466    617
#   Name: cve_primary_cwe, dtype: object),
#  (1075566600,
#   456    787
#   Name: cve_primary_cwe, dtype: object),
#  (1075634585,
#   454    787
#   Name: cve_primary_cwe, dtype: object),
#  (1075642418,
#   464    770
#   Name: cve_primary_cwe, dtype: object),
#  (1075663454,
#   467    617
#   Name: cve_primary_cwe, dtype: object),
#  (1075669945,
#   468    617
#   Name: cve_primary_cwe, dtype: object),
#  (1076499514,
#   377    416
#   Name: cve_primary_cwe, dtype: object),
#  (1076525998,
#   376    415
#   Name: cve_primary_cwe, dtype: object),
#  (1076547293,
#   382    119
#   Name: cve_primary_cwe, dtype: object),
#  (1076565216,
#   378    476
#   Name: cve_primary_cwe, dtype: object),
#  (1076568297,
#   386    835
#   Name: cve_primary_cwe, dtype: object),
#  (1076577157,
#   389    476
#   Name: cve_primary_cwe, dtype: object),
#  (1076617776,
#   388    476
#   Name: cve_primary_cwe, dtype: object),
#  (1076623517,
#   385    476
#   Name: cve_primary_cwe, dtype: object),
#  (1076656843,
#   381    476
#   Name: cve_primary_cwe, dtype: object),
#  (1076718691,
#   383    476
#   Name: cve_primary_cwe, dtype: object),
#  (1076719232,
#   396    476
#   Name: cve_primary_cwe, dtype: object),
#  (1076720063,
#   430    119
#   Name: cve_primary_cwe, dtype: object),
#  (1076915355,
#   387    476
#   Name: cve_primary_cwe, dtype: object),
#  (1076928345,
#   380    476
#   Name: cve_primary_cwe, dtype: object),
#  (1076957223,
#   384    476
#   Name: cve_primary_cwe, dtype: object),
#  (1076972078,
#   390    787
#   Name: cve_primary_cwe, dtype: object),
#  (1076993672,
#   432    119
#   Name: cve_primary_cwe, dtype: object),
#  (1077148119,
#   379    835
#   Name: cve_primary_cwe, dtype: object),
#  (1077343434,
#   394    416
#   Name: cve_primary_cwe, dtype: object),
#  (1077478008,
#   431    119
#   Name: cve_primary_cwe, dtype: object),
#  (1077478960,
#   392    476
#   Name: cve_primary_cwe, dtype: object),
#  (1077479083,
#   393    416
#   Name: cve_primary_cwe, dtype: object),
#  (1078245904,
#   437    617
#   Name: cve_primary_cwe, dtype: object),
#  (1078286757,
#   453    787
#   Name: cve_primary_cwe, dtype: object),
#  (1079233614,
#   433    119
#   Name: cve_primary_cwe, dtype: object),
#  (1079241422,
#   395    476
#   Name: cve_primary_cwe, dtype: object),
#  (1079248712,
#   391    476
#   Name: cve_primary_cwe, dtype: object),
#  (1079632902,
#   397    476
#   Name: cve_primary_cwe, dtype: object),
#  (1081062458,
#   491    79
#   Name: cve_primary_cwe, dtype: object),
#  (1086796143,
#   401    476
#   Name: cve_primary_cwe, dtype: object),
#  (1086958167,
#   398    476
#   Name: cve_primary_cwe, dtype: object),
#  (1086970623,
#   404    476
#   Name: cve_primary_cwe, dtype: object),
#  (1086980660,
#   403    476
#   Name: cve_primary_cwe, dtype: object),
#  (1086989862,
#   402    476
#   Name: cve_primary_cwe, dtype: object),
#  (1087054279,
#   407    476
#   Name: cve_primary_cwe, dtype: object),
#  (1087071987,
#   405    476
#   Name: cve_primary_cwe, dtype: object),
#  (1087094002,
#   408    476
#   Name: cve_primary_cwe, dtype: object),
#  (1088176668,
#   410    476
#   Name: cve_primary_cwe, dtype: object),
#  (1088201752,
#   409    476
#   Name: cve_primary_cwe, dtype: object),
#  (1088763905,
#   494    295
#   Name: cve_primary_cwe, dtype: object),
#  (1090357318,
#   469    89
#   Name: cve_primary_cwe, dtype: object),
#  (1091423222,
#   473    617
#   Name: cve_primary_cwe, dtype: object),
#  (1091423443,
#   477    617
#   Name: cve_primary_cwe, dtype: object),
#  (1091423652,
#   472    617
#   Name: cve_primary_cwe, dtype: object),
#  (1091423861,
#   476    617
#   Name: cve_primary_cwe, dtype: object),
#  (1091424159,
#   475    617
#   Name: cve_primary_cwe, dtype: object),
#  (1091424362,
#   470    617
#   Name: cve_primary_cwe, dtype: object),
#  (1091424556,
#   474    120
#   Name: cve_primary_cwe, dtype: object),
#  (1091424729,
#   481    120
#   Name: cve_primary_cwe, dtype: object),
#  (1091425933,
#   486    120
#   Name: cve_primary_cwe, dtype: object),
#  (1091426355,
#   484    787
#   Name: cve_primary_cwe, dtype: object),
#  (1091426673,
#   480    787
#   Name: cve_primary_cwe, dtype: object),
#  (1091426932,
#   479    787
#   Name: cve_primary_cwe, dtype: object),
#  (1091427107,
#   478    787
#   Name: cve_primary_cwe, dtype: object),
#  (1091427319,
#   482    787
#   Name: cve_primary_cwe, dtype: object),
#  (1091427555,
#   487    787
#   Name: cve_primary_cwe, dtype: object),
#  (1091427798,
#   483    787
#   Name: cve_primary_cwe, dtype: object),
#  (1091428077,
#   485    416
#   Name: cve_primary_cwe, dtype: object),
#  (1091428300,
#   471    674
#   Name: cve_primary_cwe, dtype: object),
#  (1092081853,
#   495    617
#   Name: cve_primary_cwe, dtype: object),
#  (1092198721,
#   434    416
#   Name: cve_primary_cwe, dtype: object),
#  (1092485366,
#   457    476
#   Name: cve_primary_cwe, dtype: object),
#  (1092488021,
#   458    476
#   Name: cve_primary_cwe, dtype: object),
#  (1092505386,
#   461    416
#   Name: cve_primary_cwe, dtype: object),
#  (1092514876,
#   460    787
#   Name: cve_primary_cwe, dtype: object),
#  (1092526001,
#   462    476
#   Name: cve_primary_cwe, dtype: object),
#  (1093037283,
#   443    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093037753,
#   441    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093038878,
#   439    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093040080,
#   435    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093040435,
#   442    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093041266,
#   436    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093043755,
#   440    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093045783,
#   438    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093046263,
#   448    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093046641,
#   447    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093047047,
#   445    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093047468,
#   444    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093048021,
#   449    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093048389,
#   446    617
#   Name: cve_primary_cwe, dtype: object),
#  (1093051129,
#   492    89
#   Name: cve_primary_cwe, dtype: object),
#  (1093125235,
#   493    89
#   Name: cve_primary_cwe, dtype: object),
#  (1094139713,
#   459    476
#   Name: cve_primary_cwe, dtype: object),
#  (1097120299,
#   463    476
#   Name: cve_primary_cwe, dtype: object),
#  (1107736894,
#   610    125
#   Name: cve_primary_cwe, dtype: object),
#  (1110211366,
#   506    787
#   Name: cve_primary_cwe, dtype: object),
#  (1110212655,
#   507    416
#   Name: cve_primary_cwe, dtype: object),
#  (1114645297,
#   514    190
#   Name: cve_primary_cwe, dtype: object),
#  (1117248312,
#   490    476
#   Name: cve_primary_cwe, dtype: object),
#  (1122294432,
#   497    79
#   Name: cve_primary_cwe, dtype: object),
#  (1126776763,
#   511    787
#   Name: cve_primary_cwe, dtype: object),
#  (1126777303,
#   513    416
#   Name: cve_primary_cwe, dtype: object),
#  (1139917650,
#   512    787
#   Name: cve_primary_cwe, dtype: object),
#  (1164990736,
#   505    787
#   Name: cve_primary_cwe, dtype: object),
#  (1167633442,
#   508    125
#   Name: cve_primary_cwe, dtype: object),
#  (1176173021,
#   611    787
#   Name: cve_primary_cwe, dtype: object),
#  (1180362220,
#   527    120
#   Name: cve_primary_cwe, dtype: object),
#  (1189714047,
#   522    476
#   Name: cve_primary_cwe, dtype: object),
#  (1197007820,
#   521    617
#   Name: cve_primary_cwe, dtype: object),
#  (1197113705,
#   533    352
#   Name: cve_primary_cwe, dtype: object),
#  (1198939118,
#   516    77
#   Name: cve_primary_cwe, dtype: object),
#  (1199061348,
#   529    755
#   Name: cve_primary_cwe, dtype: object),
#  (1206048984,
#   517    125
#   Name: cve_primary_cwe, dtype: object),
#  (1206053267,
#   518    125
#   Name: cve_primary_cwe, dtype: object),
#  (1212522412,
#   920    295
#   Name: cve_primary_cwe, dtype: object),
#  (1213336856,
#   545    79
#   Name: cve_primary_cwe, dtype: object),
#  (1214594854,
#   530    125
#   Name: cve_primary_cwe, dtype: object),
#  (1228840395,
#   548    770
#   Name: cve_primary_cwe, dtype: object),
#  (1228840962,
#   549    770
#   Name: cve_primary_cwe, dtype: object),
#  (1238916903,
#   546    89
#   Name: cve_primary_cwe, dtype: object),
#  (1251957111,
#   570    787
#   Name: cve_primary_cwe, dtype: object),
#  (1253977287,
#   607    835
#   Name: cve_primary_cwe, dtype: object),
#  (1262604647,
#   556    787
#   Name: cve_primary_cwe, dtype: object),
#  (1262609657,
#   555    416
#   Name: cve_primary_cwe, dtype: object),
#  (1262611394,
#   559    787
#   Name: cve_primary_cwe, dtype: object),
#  (1262613027,
#   558    787
#   Name: cve_primary_cwe, dtype: object),
#  (1262614234,
#   557    416
#   Name: cve_primary_cwe, dtype: object),
#  (1262615938,
#   554    617
#   Name: cve_primary_cwe, dtype: object),
#  (1264080771,
#   560    415
#   Name: cve_primary_cwe, dtype: object),
#  (1264082849,
#   561    787
#   Name: cve_primary_cwe, dtype: object),
#  (1274949181,
#   606    416
#   Name: cve_primary_cwe, dtype: object),
#  (1275924048,
#   598    617
#   Name: cve_primary_cwe, dtype: object),
#  (1283331255,
#   733    665
#   Name: cve_primary_cwe, dtype: object),
#  (1292105535,
#   613    787
#   Name: cve_primary_cwe, dtype: object),
#  (1292941893,
#   605    787
#   Name: cve_primary_cwe, dtype: object),
#  (1295074577,
#   604    416
#   Name: cve_primary_cwe, dtype: object),
#  (1297164642,
#   603    476
#   Name: cve_primary_cwe, dtype: object),
#  (1308022012,
#   612    78
#   Name: cve_primary_cwe, dtype: object),
#  (1331477062,
#   614    704
#   Name: cve_primary_cwe, dtype: object),
#  (1349239716,
#   643    306
#   Name: cve_primary_cwe, dtype: object),
#  (1353278230,
#   625    770
#   Name: cve_primary_cwe, dtype: object),
#  (1361905751,
#   651    787
#   Name: cve_primary_cwe, dtype: object),
#  (1361906900,
#   650    125
#   Name: cve_primary_cwe, dtype: object),
#  (1361907936,
#   652    125
#   Name: cve_primary_cwe, dtype: object),
#  (1361920430,
#   653    434
#   Name: cve_primary_cwe, dtype: object),
#  (1361978096,
#   735    787
#   Name: cve_primary_cwe, dtype: object),
#  (1362003678,
#   734    665
#   Name: cve_primary_cwe, dtype: object),
#  (1363336565,
#   616    401
#   Name: cve_primary_cwe, dtype: object),
#  (1364000633,
#   615    120
#   Name: cve_primary_cwe, dtype: object),
#  (1371299019,
#   623    78
#   Name: cve_primary_cwe, dtype: object),
#  (1372814057,
#   617    125
#   Name: cve_primary_cwe, dtype: object),
#  (1375935782,
#   967    918
#   Name: cve_primary_cwe, dtype: object),
#  (1376646543,
#   618    476
#   Name: cve_primary_cwe, dtype: object),
#  (1376678566,
#   619    476
#   Name: cve_primary_cwe, dtype: object),
#  (1376705591,
#   628    401
#   Name: cve_primary_cwe, dtype: object),
#  (1377242122,
#   642    770
#   Name: cve_primary_cwe, dtype: object),
#  (1377452573,
#   637    787
#   Name: cve_primary_cwe, dtype: object),
#  (1377456877,
#   634    401
#   Name: cve_primary_cwe, dtype: object),
#  (1377462592,
#   636    787
#   Name: cve_primary_cwe, dtype: object),
#  (1377466423,
#   635    416
#   Name: cve_primary_cwe, dtype: object),
#  (1378706570,
#   630    401
#   Name: cve_primary_cwe, dtype: object),
#  (1381208895,
#   631    401
#   Name: cve_primary_cwe, dtype: object),
#  (1383377290,
#   626    770
#   Name: cve_primary_cwe, dtype: object),
#  (1384054185,
#   632    787
#   Name: cve_primary_cwe, dtype: object),
#  (1384568694,
#   629    401
#   Name: cve_primary_cwe, dtype: object),
#  (1385048849,
#   649    401
#   Name: cve_primary_cwe, dtype: object),
#  (1386949916,
#   904    125
#   Name: cve_primary_cwe, dtype: object),
#  (1387303483,
#   624    476
#   Name: cve_primary_cwe, dtype: object),
#  (1388166902,
#   655    787
#   Name: cve_primary_cwe, dtype: object),
#  (1393638825,
#   935    125
#   Name: cve_primary_cwe, dtype: object),
#  (1395738652,
#   639    787
#   Name: cve_primary_cwe, dtype: object),
#  (1395742603,
#   638    401
#   Name: cve_primary_cwe, dtype: object),
#  (1395747445,
#   648    787
#   Name: cve_primary_cwe, dtype: object),
#  (1400040986,
#   657    401
#   Name: cve_primary_cwe, dtype: object),
#  (1402196162,
#   641    787
#   Name: cve_primary_cwe, dtype: object),
#  (1402198804,
#   640    787
#   Name: cve_primary_cwe, dtype: object),
#  (1402687023,
#   667    918
#   Name: cve_primary_cwe, dtype: object),
#  (1402818781,
#   647    416
#   Name: cve_primary_cwe, dtype: object),
#  (1403189077,
#   646    787
#   Name: cve_primary_cwe, dtype: object),
#  (1404158827,
#   658    401
#   Name: cve_primary_cwe, dtype: object),
#  (1404173443,
#   659    401
#   Name: cve_primary_cwe, dtype: object),
#  (1414350784,
#   645    476
#   Name: cve_primary_cwe, dtype: object),
#  (1414357245,
#   661    407
#   Name: cve_primary_cwe, dtype: object),
#  (1414407802,
#   644    416
#   Name: cve_primary_cwe, dtype: object),
#  (1414926196,
#   656    252
#   Name: cve_primary_cwe, dtype: object),
#  (1420268717,
#   654    787
#   Name: cve_primary_cwe, dtype: object),
#  (1421774671,
#   674    89
#   Name: cve_primary_cwe, dtype: object),
#  (1421795524,
#   673    89
#   Name: cve_primary_cwe, dtype: object),
#  (1421911807,
#   672    89
#   Name: cve_primary_cwe, dtype: object),
#  (1421998736,
#   670    89
#   Name: cve_primary_cwe, dtype: object),
#  (1422048340,
#   671    89
#   Name: cve_primary_cwe, dtype: object),
#  (1428405742,
#   679    787
#   Name: cve_primary_cwe, dtype: object),
#  (1429110423,
#   675    787
#   Name: cve_primary_cwe, dtype: object),
#  (1432381138,
#   772    119
#   Name: cve_primary_cwe, dtype: object),
#  (1438293014,
#   676    401
#   Name: cve_primary_cwe, dtype: object),
#  (1440934711,
#   724    22
#   Name: cve_primary_cwe, dtype: object),
#  (1440935103,
#   725    20
#   Name: cve_primary_cwe, dtype: object),
#  (1445073819,
#   662    787
#   Name: cve_primary_cwe, dtype: object),
#  (1446725478,
#   678    787
#   Name: cve_primary_cwe, dtype: object),
#  (1447239893,
#   677    416
#   Name: cve_primary_cwe, dtype: object),
#  (1456194214,
#   682    787
#   Name: cve_primary_cwe, dtype: object),
#  (1456453860,
#   681    787
#   Name: cve_primary_cwe, dtype: object),
#  (1456460513,
#   680    787
#   Name: cve_primary_cwe, dtype: object),
#  (1460261889,
#   774    125
#   Name: cve_primary_cwe, dtype: object),
#  (1462704527,
#   775    617
#   Name: cve_primary_cwe, dtype: object),
#  (1465089664,
#   684    122
#   Name: cve_primary_cwe, dtype: object),
#  (1465889278,
#   686    401
#   Name: cve_primary_cwe, dtype: object),
#  (1465902126,
#   685    401
#   Name: cve_primary_cwe, dtype: object),
#  (1488266227,
#   705    89
#   Name: cve_primary_cwe, dtype: object),
#  (1488308020,
#   689    120
#   Name: cve_primary_cwe, dtype: object),
#  (1488317476,
#   687    120
#   Name: cve_primary_cwe, dtype: object),
#  (1488326210,
#   688    120
#   Name: cve_primary_cwe, dtype: object),
#  (1489970920,
#   690    120
#   Name: cve_primary_cwe, dtype: object),
#  (1489981443,
#   692    416
#   Name: cve_primary_cwe, dtype: object),
#  (1489995127,
#   693    476
#   Name: cve_primary_cwe, dtype: object),
#  (1490015617,
#   694    120
#   Name: cve_primary_cwe, dtype: object),
#  (1490026124,
#   691    190
#   Name: cve_primary_cwe, dtype: object),
#  (1490145651,
#   773    125
#   Name: cve_primary_cwe, dtype: object),
#  (1491166936,
#   683    404
#   Name: cve_primary_cwe, dtype: object),
#  (1492772918,
#   695    120
#   Name: cve_primary_cwe, dtype: object),
#  (1492780269,
#   696    120
#   Name: cve_primary_cwe, dtype: object),
#  (1500560661,
#   697    120
#   Name: cve_primary_cwe, dtype: object),
#  (1501315203,
#   700    787
#   Name: cve_primary_cwe, dtype: object),
#  (1501315271,
#   698    120
#   Name: cve_primary_cwe, dtype: object),
#  (1501315341,
#   699    120
#   Name: cve_primary_cwe, dtype: object),
#  (1501315390,
#   701    190
#   Name: cve_primary_cwe, dtype: object),
#  (1501850698,
#   702    787
#   Name: cve_primary_cwe, dtype: object),
#  (1501850761,
#   703    674
#   Name: cve_primary_cwe, dtype: object),
#  (1501850806,
#   704    120
#   Name: cve_primary_cwe, dtype: object),
#  (1505891189,
#   712    79
#   Name: cve_primary_cwe, dtype: object),
#  (1531754487,
#   776    125
#   Name: cve_primary_cwe, dtype: object),
#  (1531773423,
#   777    125
#   Name: cve_primary_cwe, dtype: object),
#  (1531779880,
#   778    125
#   Name: cve_primary_cwe, dtype: object),
#  (1531809515,
#   713    502
#   Name: cve_primary_cwe, dtype: object),
#  (1552201934,
#   743    120
#   Name: cve_primary_cwe, dtype: object),
#  (1561308445,
#   726    89
#   Name: cve_primary_cwe, dtype: object),
#  (1561928009,
#   723    787
#   Name: cve_primary_cwe, dtype: object),
#  (1563517965,
#   747    74
#   Name: cve_primary_cwe, dtype: object),
#  (1567701993,
#   740    120
#   Name: cve_primary_cwe, dtype: object),
#  (1567763524,
#   739    415
#   Name: cve_primary_cwe, dtype: object),
#  (1568208539,
#   738    122
#   Name: cve_primary_cwe, dtype: object),
#  (1573731822,
#   771    476
#   Name: cve_primary_cwe, dtype: object),
#  (1575489854,
#   769    787
#   Name: cve_primary_cwe, dtype: object),
#  (1575501548,
#   770    787
#   Name: cve_primary_cwe, dtype: object),
#  (1577978840,
#   721    787
#   Name: cve_primary_cwe, dtype: object),
#  (1581285056,
#   744    330
#   Name: cve_primary_cwe, dtype: object),
#  (1583115861,
#   746    74
#   Name: cve_primary_cwe, dtype: object),
#  (1590603154,
#   737    79
#   Name: cve_primary_cwe, dtype: object),
#  (1591349265,
#   741    280
#   Name: cve_primary_cwe, dtype: object),
#  (1595844394,
#   722    20
#   Name: cve_primary_cwe, dtype: object),
#  (1598184264,
#   828    89
#   Name: cve_primary_cwe, dtype: object),
#  (1602439311,
#   783    787
#   Name: cve_primary_cwe, dtype: object),
#  (1610480695,
#   753    476
#   Name: cve_primary_cwe, dtype: object),
#  (1610488659,
#   759    770
#   Name: cve_primary_cwe, dtype: object),
#  (1610494409,
#   751    119
#   Name: cve_primary_cwe, dtype: object),
#  (1618118032,
#   830    116
#   Name: cve_primary_cwe, dtype: object),
#  (1622614615,
#   752    770
#   Name: cve_primary_cwe, dtype: object),
#  (1622623759,
#   749    119
#   Name: cve_primary_cwe, dtype: object),
#  (1622631441,
#   755    770
#   Name: cve_primary_cwe, dtype: object),
#  (1622665090,
#   763    787
#   Name: cve_primary_cwe, dtype: object),
#  (1623402397,
#   748    125
#   Name: cve_primary_cwe, dtype: object),
#  (1624874619,
#   762    787
#   Name: cve_primary_cwe, dtype: object),
#  (1633318454,
#   785    120
#   Name: cve_primary_cwe, dtype: object),
#  (1633322109,
#   787    120
#   Name: cve_primary_cwe, dtype: object),
#  (1633325057,
#   786    125
#   Name: cve_primary_cwe, dtype: object),
#  (1634994366,
#   927    89
#   Name: cve_primary_cwe, dtype: object),
#  (1635357898,
#   789    119
#   Name: cve_primary_cwe, dtype: object),
#  (1635358781,
#   788    787
#   Name: cve_primary_cwe, dtype: object),
#  (1638659213,
#   754    20
#   Name: cve_primary_cwe, dtype: object),
#  (1641737938,
#   761    400
#   Name: cve_primary_cwe, dtype: object),
#  (1642781849,
#   768    835
#   Name: cve_primary_cwe, dtype: object),
#  (1643268712,
#   760    400
#   Name: cve_primary_cwe, dtype: object),
#  (1646878719,
#   889    787
#   890    787
#   Name: cve_primary_cwe, dtype: object),
#  (1648637134,
#   887    787
#   888    787
#   Name: cve_primary_cwe, dtype: object),
#  (1657176424,
#   794    617
#   Name: cve_primary_cwe, dtype: object),
#  (1657404755,
#   796    617
#   Name: cve_primary_cwe, dtype: object),
#  (1657488796,
#   797    617
#   Name: cve_primary_cwe, dtype: object),
#  (1659514220,
#   790    787
#   Name: cve_primary_cwe, dtype: object),
#  (1659524592,
#   792    787
#   Name: cve_primary_cwe, dtype: object),
#  (1659537585,
#   800    617
#   Name: cve_primary_cwe, dtype: object),
#  (1659728699,
#   909    787
#   Name: cve_primary_cwe, dtype: object),
#  (1659731495,
#   910    400
#   Name: cve_primary_cwe, dtype: object),
#  (1659733406,
#   911    400
#   Name: cve_primary_cwe, dtype: object),
#  (1659734429,
#   912    400
#   Name: cve_primary_cwe, dtype: object),
#  (1659749340,
#   913    400
#   Name: cve_primary_cwe, dtype: object),
#  (1661128936,
#   808    89
#   Name: cve_primary_cwe, dtype: object),
#  (1664162150,
#   857    787
#   Name: cve_primary_cwe, dtype: object),
#  (1664179606,
#   854    787
#   Name: cve_primary_cwe, dtype: object),
#  (1664192034,
#   858    787
#   Name: cve_primary_cwe, dtype: object),
#  (1665051847,
#   804    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665059115,
#   805    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665064064,
#   801    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665069177,
#   807    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665070884,
#   810    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665072694,
#   802    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665074357,
#   809    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665077173,
#   806    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665085302,
#   803    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665089526,
#   811    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665092932,
#   814    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665108794,
#   820    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665110745,
#   815    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665114015,
#   817    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665117118,
#   819    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665120116,
#   813    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665123657,
#   818    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665127014,
#   816    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665129009,
#   812    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665131513,
#   825    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665134343,
#   824    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665136195,
#   823    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665138910,
#   821    89
#   Name: cve_primary_cwe, dtype: object),
#  (1665143521,
#   822    89
#   Name: cve_primary_cwe, dtype: object),
#  (1668392801,
#   849    770
#   Name: cve_primary_cwe, dtype: object),
#  (1668648319,
#   850    770
#   859    416
#   Name: cve_primary_cwe, dtype: object),
#  (1669965859,
#   798    617
#   Name: cve_primary_cwe, dtype: object),
#  (1670071780,
#   826    79
#   Name: cve_primary_cwe, dtype: object),
#  (1673423197,
#   863    416
#   Name: cve_primary_cwe, dtype: object),
#  (1673473933,
#   862    787
#   Name: cve_primary_cwe, dtype: object),
#  (1674113082,
#   799    617
#   Name: cve_primary_cwe, dtype: object),
#  (1674723917,
#   795    770
#   Name: cve_primary_cwe, dtype: object),
#  (1674802543,
#   791    787
#   Name: cve_primary_cwe, dtype: object),
#  (1678971305,
#   892    79
#   Name: cve_primary_cwe, dtype: object),
#  (1680076342,
#   793    787
#   Name: cve_primary_cwe, dtype: object),
#  (1682097315,
#   891    674
#   Name: cve_primary_cwe, dtype: object),
#  (1682372017,
#   856    416
#   Name: cve_primary_cwe, dtype: object),
#  (1690372075,
#   831    352
#   Name: cve_primary_cwe, dtype: object),
#  (1693458747,
#   832    89
#   Name: cve_primary_cwe, dtype: object),
#  (1695904246,
#   833    89
#   Name: cve_primary_cwe, dtype: object),
#  (1701910416,
#   934    94
#   Name: cve_primary_cwe, dtype: object),
#  (1704361322,
#   952    120
#   Name: cve_primary_cwe, dtype: object),
#  (1709406655,
#   864    732
#   Name: cve_primary_cwe, dtype: object),
#  (1713432787,
#   853    77
#   Name: cve_primary_cwe, dtype: object),
#  (1713528731,
#   852    78
#   Name: cve_primary_cwe, dtype: object),
#  (1713682055,
#   851    190
#   Name: cve_primary_cwe, dtype: object),
#  (1724968984,
#   869    89
#   Name: cve_primary_cwe, dtype: object),
#  (1725285095,
#   867    89
#   Name: cve_primary_cwe, dtype: object),
#  (1727638418,
#   872    89
#   Name: cve_primary_cwe, dtype: object),
#  (1727654900,
#   873    89
#   Name: cve_primary_cwe, dtype: object),
#  (1729493887,
#   870    434
#   Name: cve_primary_cwe, dtype: object),
#  (1734082739,
#   866    617
#   Name: cve_primary_cwe, dtype: object),
#  (1738671677,
#   855    532
#   Name: cve_primary_cwe, dtype: object),
#  (1741623530,
#   865    617
#   Name: cve_primary_cwe, dtype: object),
#  (1747393600,
#   897    94
#   Name: cve_primary_cwe, dtype: object),
#  (1749279355,
#   898    89
#   Name: cve_primary_cwe, dtype: object),
#  (1752341840,
#   1039    400
#   Name: cve_primary_cwe, dtype: object),
#  (1752379751,
#   1040    400
#   Name: cve_primary_cwe, dtype: object),
#  (1752392145,
#   1042    476
#   Name: cve_primary_cwe, dtype: object),
#  (1752398555,
#   1043    476
#   Name: cve_primary_cwe, dtype: object),
#  (1754192903,
#   886    120
#   Name: cve_primary_cwe, dtype: object),
#  (1755056681,
#   896    20
#   Name: cve_primary_cwe, dtype: object),
#  (1755936135,
#   714    89
#   Name: cve_primary_cwe, dtype: object),
#  (1758988605,
#   868    1287
#   Name: cve_primary_cwe, dtype: object),
#  (1760900711,
#   877    770
#   Name: cve_primary_cwe, dtype: object),
#  (1760991161,
#   880    770
#   Name: cve_primary_cwe, dtype: object),
#  (1760998433,
#   879    770
#   Name: cve_primary_cwe, dtype: object),
#  (1761007588,
#   878    770
#   Name: cve_primary_cwe, dtype: object),
#  (1761035852,
#   882    770
#   Name: cve_primary_cwe, dtype: object),
#  (1761077451,
#   881    770
#   Name: cve_primary_cwe, dtype: object),
#  (1761117903,
#   875    89
#   Name: cve_primary_cwe, dtype: object),
#  (1761134477,
#   883    770
#   Name: cve_primary_cwe, dtype: object),
#  (1761137805,
#   876    89
#   Name: cve_primary_cwe, dtype: object),
#  (1761141292,
#   874    89
#   Name: cve_primary_cwe, dtype: object),
#  (1772536756,
#   931    787
#   Name: cve_primary_cwe, dtype: object),
#  (1776376880,
#   905    787
#   Name: cve_primary_cwe, dtype: object),
#  (1780762234,
#   936    426
#   Name: cve_primary_cwe, dtype: object),
#  (1787177384,
#   908    787
#   Name: cve_primary_cwe, dtype: object),
#  (1787186997,
#   906    787
#   Name: cve_primary_cwe, dtype: object),
#  (1787914764,
#   907    787
#   Name: cve_primary_cwe, dtype: object),
#  (1802378837,
#   926    94
#   Name: cve_primary_cwe, dtype: object),
#  (1805330606,
#   960    20
#   Name: cve_primary_cwe, dtype: object),
#  (1815528659,
#   919    89
#   Name: cve_primary_cwe, dtype: object),
#  (1818405399,
#   937    416
#   Name: cve_primary_cwe, dtype: object),
#  (1822676744,
#   966    20
#   Name: cve_primary_cwe, dtype: object),
#  (1822677454,
#   961    20
#   Name: cve_primary_cwe, dtype: object),
#  (1840701677,
#   943    416
#   Name: cve_primary_cwe, dtype: object),
#  (1842363544,
#   938    787
#   Name: cve_primary_cwe, dtype: object),
#  (1867152632,
#   939    89
#   Name: cve_primary_cwe, dtype: object),
#  (1871078948,
#   956    190
#   Name: cve_primary_cwe, dtype: object),
#  (1871446973,
#   1034    401
#   Name: cve_primary_cwe, dtype: object),
#  (1873179897,
#   941    120
#   Name: cve_primary_cwe, dtype: object),
#  (1873333053,
#   940    120
#   Name: cve_primary_cwe, dtype: object),
#  (1879420551,
#   942    120
#   Name: cve_primary_cwe, dtype: object),
#  (1887469185,
#   948    434
#   Name: cve_primary_cwe, dtype: object),
#  (1887485959,
#   945    22
#   Name: cve_primary_cwe, dtype: object),
#  (1887497669,
#   949    116
#   Name: cve_primary_cwe, dtype: object),
#  (1887513001,
#   946    200
#   Name: cve_primary_cwe, dtype: object),
#  (1887526520,
#   947    311
#   Name: cve_primary_cwe, dtype: object),
#  (1899819562,
#   953    787
#   Name: cve_primary_cwe, dtype: object),
#  (1902565722,
#   1045    129
#   Name: cve_primary_cwe, dtype: object),
#  (1902573548,
#   1044    79
#   Name: cve_primary_cwe, dtype: object),
#  (1902581538,
#   1047    330
#   Name: cve_primary_cwe, dtype: object),
#  (1902586609,
#   1046    290
#   Name: cve_primary_cwe, dtype: object),
#  (1902619338,
#   1048    601
#   Name: cve_primary_cwe, dtype: object),
#  (1902637888,
#   1049    116
#   Name: cve_primary_cwe, dtype: object),
#  (1908102486,
#   969    120
#   Name: cve_primary_cwe, dtype: object),
#  (1908115920,
#   978    120
#   Name: cve_primary_cwe, dtype: object),
#  (1913517983,
#   1012    125
#   Name: cve_primary_cwe, dtype: object),
#  (1931687191,
#   959    125
#   Name: cve_primary_cwe, dtype: object),
#  (1931692043,
#   958    787
#   Name: cve_primary_cwe, dtype: object),
#  (1931883357,
#   975    416
#   Name: cve_primary_cwe, dtype: object),
#  (1931884388,
#   976    415
#   Name: cve_primary_cwe, dtype: object),
#  (1931886016,
#   977    787
#   Name: cve_primary_cwe, dtype: object),
#  (1934290908,
#   968    120
#   Name: cve_primary_cwe, dtype: object),
#  (1956040458,
#   964    787
#   Name: cve_primary_cwe, dtype: object),
#  (1956459097,
#   991    401
#   Name: cve_primary_cwe, dtype: object),
#  (1958731162,
#   965    787
#   Name: cve_primary_cwe, dtype: object),
#  (1959013436,
#   979    120
#   Name: cve_primary_cwe, dtype: object),
#  (1959261781,
#   963    787
#   Name: cve_primary_cwe, dtype: object),
#  (1960612139,
#   962    787
#   Name: cve_primary_cwe, dtype: object),
#  (1960809373,
#   1007    94
#   Name: cve_primary_cwe, dtype: object),
#  (1964116818,
#   994    787
#   Name: cve_primary_cwe, dtype: object),
#  (1966977323,
#   980    400
#   Name: cve_primary_cwe, dtype: object),
#  (1971994862,
#   970    401
#   Name: cve_primary_cwe, dtype: object),
#  (1977696903,
#   1010    416
#   Name: cve_primary_cwe, dtype: object),
#  (1980426267,
#   982    401
#   Name: cve_primary_cwe, dtype: object),
#  (1980712658,
#   983    401
#   Name: cve_primary_cwe, dtype: object),
#  (1982577272,
#   974    79
#   Name: cve_primary_cwe, dtype: object),
#  (1982605023,
#   973    732
#   Name: cve_primary_cwe, dtype: object),
#  (1989816339,
#   1001    697
#   Name: cve_primary_cwe, dtype: object),
#  (1989818650,
#   997    120
#   Name: cve_primary_cwe, dtype: object),
#  (1989824628,
#   998    787
#   Name: cve_primary_cwe, dtype: object),
#  (1989826100,
#   1000    120
#   Name: cve_primary_cwe, dtype: object),
#  (1989827779,
#   999    787
#   Name: cve_primary_cwe, dtype: object),
#  (1992885538,
#   988    787
#   Name: cve_primary_cwe, dtype: object),
#  (1992951081,
#   989    502
#   Name: cve_primary_cwe, dtype: object),
#  (1993034362,
#   971    20
#   Name: cve_primary_cwe, dtype: object),
#  (1995888449,
#   992    401
#   Name: cve_primary_cwe, dtype: object),
#  (1998710063,
#   1135    787
#   1136    787
#   Name: cve_primary_cwe, dtype: object),
#  (1998711622,
#   1011    787
#   Name: cve_primary_cwe, dtype: object),
#  (2004741539,
#   1139    787
#   Name: cve_primary_cwe, dtype: object),
#  (2007422344,
#   1005    120
#   Name: cve_primary_cwe, dtype: object),
#  (2007974265,
#   993    269
#   Name: cve_primary_cwe, dtype: object),
#  (2010943506,
#   1014    125
#   Name: cve_primary_cwe, dtype: object),
#  (2010974674,
#   1013    20
#   Name: cve_primary_cwe, dtype: object),
#  (2020058777,
#   1016    835
#   Name: cve_primary_cwe, dtype: object),
#  (2031418685,
#   1006    120
#   Name: cve_primary_cwe, dtype: object),
#  (2035564943,
#   1008    835
#   Name: cve_primary_cwe, dtype: object),
#  (2039038848,
#   1009    787
#   Name: cve_primary_cwe, dtype: object),
#  (2054769328,
#   1018    79
#   Name: cve_primary_cwe, dtype: object),
#  (2057585750,
#   1137    416
#   1138    416
#   Name: cve_primary_cwe, dtype: object),
#  (2068418306,
#   1030    120
#   Name: cve_primary_cwe, dtype: object),
#  (2076500051,
#   1038    918
#   Name: cve_primary_cwe, dtype: object),
#  (2079829395,
#   1051    401
#   Name: cve_primary_cwe, dtype: object),
#  (2079890770,
#   1054    401
#   Name: cve_primary_cwe, dtype: object),
#  (2079896237,
#   1053    401
#   Name: cve_primary_cwe, dtype: object),
#  (2079901582,
#   1052    401
#   Name: cve_primary_cwe, dtype: object),
#  (2080480764,
#   1055    401
#   Name: cve_primary_cwe, dtype: object),
#  (2128477169,
#   1050    79
#   Name: cve_primary_cwe, dtype: object),
#  (2277546456,
#   1215    787
#   Name: cve_primary_cwe, dtype: object),
#  (2325854595,
#   1214    416
#   Name: cve_primary_cwe, dtype: object),
#  (2348153606,
#   1085    835
#   Name: cve_primary_cwe, dtype: object),
#  (2348155759,
#   1086    476
#   Name: cve_primary_cwe, dtype: object),
#  (2348158622,
#   1087    476
#   Name: cve_primary_cwe, dtype: object),
#  (2348161533,
#   1088    416
#   Name: cve_primary_cwe, dtype: object),
#  (2353847380,
#   1219    732
#   Name: cve_primary_cwe, dtype: object),
#  (2354037707,
#   1218    281
#   Name: cve_primary_cwe, dtype: object),
#  (2354120170,
#   1220    281
#   Name: cve_primary_cwe, dtype: object),
#  (2370218387,
#   1224    476
#   Name: cve_primary_cwe, dtype: object),
#  (2372307138,
#   1221    281
#   Name: cve_primary_cwe, dtype: object),
#  (2374591094,
#   1216    281
#   Name: cve_primary_cwe, dtype: object),
#  (2374628765,
#   1217    281
#   Name: cve_primary_cwe, dtype: object),
#  (2386893180,
#   1131    1333
#   Name: cve_primary_cwe, dtype: object),
#  (2403698799,
#   1129    94
#   Name: cve_primary_cwe, dtype: object),
#  (2403698874,
#   1128    94
#   Name: cve_primary_cwe, dtype: object),
#  (2403698934,
#   1125    94
#   Name: cve_primary_cwe, dtype: object),
#  (2403699035,
#   1127    94
#   Name: cve_primary_cwe, dtype: object),
#  (2403699086,
#   1126    94
#   Name: cve_primary_cwe, dtype: object),
#  (2404828568,
#   1130    94
#   Name: cve_primary_cwe, dtype: object),
#  (2411949445,
#   1223    476
#   Name: cve_primary_cwe, dtype: object),
#  (2421255890,
#   1222    476
#   Name: cve_primary_cwe, dtype: object),
#  (2424146540,
#   1111    276
#   Name: cve_primary_cwe, dtype: object),
#  (2470285353,
#   1115    1333
#   Name: cve_primary_cwe, dtype: object),
#  (2551940669,
#   1164    77
#   Name: cve_primary_cwe, dtype: object),
#  (2570129601,
#   1238    476
#   Name: cve_primary_cwe, dtype: object),
#  (2570257093,
#   1237    787
#   Name: cve_primary_cwe, dtype: object),
#  (2581923723,
#   1159    798
#   Name: cve_primary_cwe, dtype: object),
#  (2581924154,
#   1160    798
#   Name: cve_primary_cwe, dtype: object),
#  (2827107053,
#   1243    79
#   Name: cve_primary_cwe, dtype: object),
#  (2829779628,
#   1244    89
#   Name: cve_primary_cwe, dtype: object),
#  (2839503293,
#   1245    79
#   Name: cve_primary_cwe, dtype: object),
#  (2839506809,
#   1246    89
#   Name: cve_primary_cwe, dtype: object),
#  (2839508441,
#   1247    89
#   Name: cve_primary_cwe, dtype: object),
#  (2839513942,
#   1248    89
#   Name: cve_primary_cwe, dtype: object),
#  (2839516802,
#   1249    89
#   Name: cve_primary_cwe, dtype: object)]
# Original length: 903
# After dropping inconsistent duplicates: 866
# 866

# %% [markdown]
# Now we want to redice the dimension of the negative part of the dataset. One way it's to set a limit of maximum 1200 issues for each repo (the maximum number of reference per repo is 200)

# %%
negative_df.issue_owner_repo.count(), positive_df.issue_owner_repo.count()
# Out:
# (np.int64(88335), np.int64(903))

# %%
filtered_negative_df = None
ratio = 5

for index, value in zip(
    positive_df.issue_owner_repo.value_counts().index,
    positive_df.issue_owner_repo.value_counts(),
):
    mask = negative_df.issue_owner_repo.map(
        lambda x: True if (index[0] == x[0] and index[1] == x[1]) else False
    )

    tmp = (
        negative_df[mask]
        .sort_values(by="issue_created_at", ascending=False)
        .head(value * ratio)
    )
    if filtered_negative_df is not None:
        filtered_negative_df = pd.concat([filtered_negative_df, tmp], ignore_index=True)
    else:
        filtered_negative_df = tmp.copy()

negative_df = filtered_negative_df
filtered_negative_df.issue_owner_repo.value_counts()
# Out:
# issue_owner_repo
# (gpac, gpac)                          1013
# (ImageMagick, ImageMagick)             370
# (LibreDWG, libredwg)                   345
# (axiomatic-systems, Bento4)            312
# (jerryscript-project, jerryscript)     258
# (kubernetes, kubernetes)               220
# (openlink, virtuoso-opensource)        135
# (Piwigo, Piwigo)                       120
# (cesanta, mjs)                         101
# (jeecgboot, jeecg-boot)                100
# (libming, libming)                      97
# (ChurchCRM, CRM)                        75
# (python, cpython)                       65
# (dromara, hutool)                       65
# (xuxueli, xxl-job)                      60
# (MonetDB, MonetDB)                      55
# (emqx, nanomq)                          55
# (ros-navigation, navigation2)           55
# (WebAssembly, wabt)                     55
# (llvm, llvm-project)                    40
# (MiczFlor, RPi-Jukebox-RFID)            35
# (free5gc, free5gc)                      35
# (micropython, micropython)              35
# (hwchase17, langchain)                  30
# (greenpau, caddy-security)              30
# (chakra-core, ChakraCore)               25
# (schollz, croc)                         25
# (espeak-ng, espeak-ng)                  25
# Name: count, dtype: int64

# %%
negative_df.issue_owner_repo.count(), positive_df.issue_owner_repo.count()
# Out:
# (np.int64(88335), np.int64(903))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

k = 40
data = positive_df[positive_df["cve_primary_cwe"].apply(lambda x: x != None)][
    "cve_primary_cwe"
].value_counts(normalize=False)
data_df = data.head(40).reset_index()
data_df.columns = ["CWE", "Proportion"]
print("data len:\t", len(data))
display(data_df.head(10))
# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x="CWE", y="Proportion", hue="CWE", data=data_df, palette="viridis")

# Add labels and title
plt.xticks(rotation=45, ha="right")
plt.title(f"Proportion of top {k} CWEs")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# data len:	 71
#    CWE  Proportion
# 0  787         182
# 1  476         134
# 2  125          69
# 3   89          64
# 4  401          63
# 5  617          51
# 6  416          46
# 7  120          40
# 8  770          40
# 9   79          23

# %% [markdown]
# ## Creating labels and marge

# %%
positive_df["label"] = True
negative_df["label"] = False

# %%
display(positive_df.columns)
display(negative_df.columns)
# Out:
# Index(['cve_id', 'cve_published', 'cve_descriptions', 'cve_metrics',
#        'cve_references', 'cve_configurations', 'cve_cwe_list',
#        'cve_primary_cwe', 'url', 'cve_tags', 'domain', 'issue_owner_repo',
#        'issue_body', 'issue_title', 'issue_comments_url',
#        'issue_comments_count', 'issue_created_at', 'issue_updated_at',
#        'issue_html_url', 'issue_github_id', 'issue_number', 'label'],
#       dtype='object')
# Index(['issue_owner_repo', 'issue_body', 'issue_title', 'issue_comments_url',
#        'issue_comments_count', 'issue_created_at', 'issue_updated_at',
#        'issue_html_url', 'issue_github_id', 'issue_number', 'label'],
#       dtype='object')

# %%
import pandas as pd

positive_df = positive_df.drop(columns=["url", "domain", "cve_cwe_list"])
display(positive_df.columns)
final_df = pd.concat([positive_df, negative_df], axis=0)
final_df.reset_index(drop=True, inplace=True)
# Out:
# Index(['cve_id', 'cve_published', 'cve_descriptions', 'cve_metrics',
#        'cve_references', 'cve_configurations', 'cve_primary_cwe', 'cve_tags',
#        'issue_owner_repo', 'issue_body', 'issue_title', 'issue_comments_url',
#        'issue_comments_count', 'issue_created_at', 'issue_updated_at',
#        'issue_html_url', 'issue_github_id', 'issue_number', 'label'],
#       dtype='object')

# %%
display(final_df.columns)
display(final_df)
# Out:
# Index(['cve_id', 'cve_published', 'cve_descriptions', 'cve_metrics',
#        'cve_references', 'cve_configurations', 'cve_primary_cwe', 'cve_tags',
#        'issue_owner_repo', 'issue_body', 'issue_title', 'issue_comments_url',
#        'issue_comments_count', 'issue_created_at', 'issue_updated_at',
#        'issue_html_url', 'issue_github_id', 'issue_number', 'label'],
#       dtype='object')
#               cve_id            cve_published  \
# 0     CVE-2018-20659  2019-01-02T17:29:00.220
# 1      CVE-2019-6132  2019-01-11T05:29:01.763
# 2      CVE-2019-6966  2019-01-25T23:29:00.237
# 3      CVE-2019-7395  2019-02-05T00:29:00.400
# 4      CVE-2019-7396  2019-02-05T00:29:00.447
# ...              ...                      ...
# 4734             NaN                      NaN
# 4735             NaN                      NaN
# 4736             NaN                      NaN
# 4737             NaN                      NaN
# 4738             NaN                      NaN
#
#                                        cve_descriptions  \
# 0     An issue was discovered in Bento4 1.5.1-627. T...
# 1     An issue was discovered in Bento4 v1.5.1-627. ...
# 2     An issue was discovered in Bento4 1.5.1-628. T...
# 3     In ImageMagick before 7.0.8-25, a memory leak ...
# 4     In ImageMagick before 7.0.8-25, a memory leak ...
# ...                                                 ...
# 4734                                                NaN
# 4735                                                NaN
# 4736                                                NaN
# 4737                                                NaN
# 4738                                                NaN
#
#                                             cve_metrics  \
# 0     {'cvssMetricV2': [{'acInsufInfo': False, 'base...
# 1     {'cvssMetricV2': [{'acInsufInfo': False, 'base...
# 2     {'cvssMetricV2': [{'acInsufInfo': False, 'base...
# 3     {'cvssMetricV2': [{'acInsufInfo': False, 'base...
# 4     {'cvssMetricV2': [{'acInsufInfo': False, 'base...
# ...                                                 ...
# 4734                                                NaN
# 4735                                                NaN
# 4736                                                NaN
# 4737                                                NaN
# 4738                                                NaN
#
#                                          cve_references  \
# 0     [{'source': 'cve@mitre.org', 'tags': ['Exploit...
# 1     [{'source': 'cve@mitre.org', 'tags': ['Exploit...
# 2     [{'source': 'cve@mitre.org', 'tags': ['Exploit...
# 3     [{'source': 'cve@mitre.org', 'tags': ['Broken ...
# 4     [{'source': 'cve@mitre.org', 'tags': ['Broken ...
# ...                                                 ...
# 4734                                                NaN
# 4735                                                NaN
# 4736                                                NaN
# 4737                                                NaN
# 4738                                                NaN
#
#                                      cve_configurations cve_primary_cwe  \
# 0     [{'nodes': [{'cpeMatch': array([{'criteria': '...             770
# 1     [{'nodes': [{'cpeMatch': array([{'criteria': '...             401
# 2     [{'nodes': [{'cpeMatch': array([{'criteria': '...             770
# 3     [{'nodes': [{'cpeMatch': array([{'criteria': '...             401
# 4     [{'nodes': [{'cpeMatch': array([{'criteria': '...             401
# ...                                                 ...             ...
# 4734                                                NaN             NaN
# 4735                                                NaN             NaN
# 4736                                                NaN             NaN
# 4737                                                NaN             NaN
# 4738                                                NaN             NaN
#
#                                     cve_tags             issue_owner_repo  \
# 0            [Exploit, Third Party Advisory]  (axiomatic-systems, Bento4)
# 1            [Exploit, Third Party Advisory]  (axiomatic-systems, Bento4)
# 2            [Exploit, Third Party Advisory]  (axiomatic-systems, Bento4)
# 3     [Exploit, Patch, Third Party Advisory]   (ImageMagick, ImageMagick)
# 4     [Exploit, Patch, Third Party Advisory]   (ImageMagick, ImageMagick)
# ...                                      ...                          ...
# 4734                                     NaN       (espeak-ng, espeak-ng)
# 4735                                     NaN       (espeak-ng, espeak-ng)
# 4736                                     NaN       (espeak-ng, espeak-ng)
# 4737                                     NaN       (espeak-ng, espeak-ng)
# 4738                                     NaN       (espeak-ng, espeak-ng)
#
#                                              issue_body  \
# 0     A crafted input will lead to Memory allocation...
# 1     there is memory leaks in Ap4String.cpp\r\n\r\n...
# 2     A crafted input will lead to  failed  allocate...
# 3     ### Prerequisites\r\n\r\n- [x] I have written ...
# 4     ### Prerequisites\r\n\r\n- [x] I have written ...
# ...                                                 ...
# 4734  Hello,\r\n\r\nWhile working on https://github....
# 4735  Speakers\t44 million (2017–2021)\r\n\r\nhttps:...
# 4736  While using NVDA 2024.4.1 with eSpeak NG 1.52,...
# 4737  My build is failing and looking at the Makefil...
# 4738  ALSA lib confmisc.c:855:(parse_card) cannot fi...
#
#                                             issue_title  \
# 0     Allocate for large amounts of memory failed in...
# 1                         memory leaks in Ap4String.cpp
# 2      failed to allocate LargeMmapAllocator in Ap4A...
# 3        memory leak in WritePSDChannel in coders/psd.c
# 4     Potential Memory Leak in ReadSIXELImage in cod...
# ...                                                 ...
# 4734         Does WAVE2 processing require wav scaling?
# 4735                [FR] Append Pashtoo language please
# 4736                          Strange mispronunciations
# 4737  Build Failure During espeak-ng Compile Binary ...
# 4738                                         [bug] alsa
#
#                                      issue_comments_url  issue_comments_count  \
# 0     https://api.github.com/repos/axiomatic-systems...                     2
# 1     https://api.github.com/repos/axiomatic-systems...                     1
# 2     https://api.github.com/repos/axiomatic-systems...                     1
# 3     https://api.github.com/repos/ImageMagick/Image...                     2
# 4     https://api.github.com/repos/ImageMagick/Image...                     2
# ...                                                 ...                   ...
# 4734  https://api.github.com/repos/espeak-ng/espeak-...                     0
# 4735  https://api.github.com/repos/espeak-ng/espeak-...                     1
# 4736  https://api.github.com/repos/espeak-ng/espeak-...                     1
# 4737  https://api.github.com/repos/espeak-ng/espeak-...                     1
# 4738  https://api.github.com/repos/espeak-ng/espeak-...                     2
#
#         issue_created_at      issue_updated_at  \
# 0    2018-12-31 15:52:26  2019-01-12T21:14:48Z
# 1    2019-01-10 17:00:31  2019-01-12T09:36:13Z
# 2    2019-01-25 07:49:22  2019-12-26T14:50:59Z
# 3    2019-01-17 03:11:55  2019-02-12T01:45:47Z
# 4    2019-01-17 04:06:51  2019-03-11T01:54:07Z
# ...                  ...                   ...
# 4734 2024-12-15 23:20:20  2024-12-15T23:20:20Z
# 4735 2024-12-06 09:57:44  2025-02-16T07:16:02Z
# 4736 2024-12-06 02:24:02  2024-12-07T22:40:43Z
# 4737 2024-12-04 16:35:09  2024-12-04T21:46:06Z
# 4738 2024-11-26 07:59:22  2025-01-01T13:04:06Z
#
#                                          issue_html_url  issue_github_id  \
# 0     https://github.com/axiomatic-systems/Bento4/is...        394998583
# 1     https://github.com/axiomatic-systems/Bento4/is...        397925621
# 2     https://github.com/axiomatic-systems/Bento4/is...        403042062
# 3     https://github.com/ImageMagick/ImageMagick/iss...        400092278
# 4     https://github.com/ImageMagick/ImageMagick/iss...        400102085
# ...                                                 ...              ...
# 4734  https://github.com/espeak-ng/espeak-ng/issues/...       2740973470
# 4735  https://github.com/espeak-ng/espeak-ng/issues/...       2722580509
# 4736  https://github.com/espeak-ng/espeak-ng/issues/...       2721891597
# 4737  https://github.com/espeak-ng/espeak-ng/issues/...       2718269469
# 4738  https://github.com/espeak-ng/espeak-ng/issues/...       2693618777
#
#       issue_number  label
# 0              350   True
# 1              357   True
# 2              361   True
# 3             1451   True
# 4             1452   True
# ...            ...    ...
# 4734          2075  False
# 4735          2051  False
# 4736          2050  False
# 4737          2048  False
# 4738          2041  False
#
# [4739 rows x 19 columns]

# %% [markdown]
# # Create issue message and embedding

# %%
# import genai
import os
import tiktoken
from pandarallel import pandarallel
from utils import load_prompts

pandarallel.initialize(progress_bar=False)
encoding = tiktoken.encoding_for_model("text-embedding-3-large")
prompts_dict = load_prompts(os.getcwd() + "/prompts")


def foo(x):
    return prompts_dict["issues_display"].format(
        title=x["issue_title"],
        body=x["issue_body"],
        repo_owner=x["issue_owner_repo"][0],
        repo_name=x["issue_owner_repo"][1],
    )
# Out:
# INFO: Pandarallel will run on 16 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
final_df["issue_msg"] = final_df.parallel_apply(foo, axis=1)
final_df["issue_msg_n_tokens"] = final_df.issue_msg.parallel_map(encoding.encode)
final_df["issue_msg_n_tokens"] = final_df.issue_msg.parallel_map(len)

# %%
# remove all entry with a context window > 8191
final_df = final_df[final_df.issue_msg_n_tokens < 8191]

# %%
final_df["cve_primary_cwe"] = final_df["cve_primary_cwe"].fillna("No_CWE")
display(final_df[["cve_primary_cwe"]])
# Out:
#      cve_primary_cwe
# 1                401
# 3                401
# 4                401
# 5                401
# 6                401
# ...              ...
# 4734          No_CWE
# 4735          No_CWE
# 4736          No_CWE
# 4737          No_CWE
# 4738          No_CWE
#
# [4445 rows x 1 columns]

# %%
len(final_df['cve_primary_cwe'].value_counts())
usage_dict_1003 = pd.Series(
    cwe_1003_df.MappingNotes_Usage.values, index=cwe_1003_df.ID
).to_dict()
print(len(final_df[final_df['cve_primary_cwe'].isin(usage_dict_1003)])/len(final_df))
# Out:
# 0.1793025871766029

# %%
print(len(final_df))
cwe_counts = final_df['cve_primary_cwe'].value_counts()
display(cwe_counts.head())
# Step 2: Filter the DataFrame to include only rows where 'cve_primary_cwe' appears more than once
final_df = final_df[final_df['cve_primary_cwe'].map(cwe_counts) > 2]
print(len(final_df))
print(len(final_df['cve_primary_cwe'].value_counts()))
# Out:
# 4445
# cve_primary_cwe
# No_CWE    3640
# 787        156
# 476        120
# 89          64
# 125         61
# Name: count, dtype: int64
# 4400
# 33

# %%
display(final_df['cve_primary_cwe'].value_counts())
# Out:
# cve_primary_cwe
# No_CWE    3640
# 787        156
# 476        120
# 89          64
# 125         61
# 401         51
# 617         48
# 120         39
# 770         36
# 416         31
# 79          23
# 400         14
# 119         13
# 415         12
# 20          10
# 94          10
# 190          8
# 835          7
# 532          6
# 732          5
# 369          5
# 665          5
# 601          4
# 674          4
# 918          4
# 22           3
# 763          3
# 77           3
# 352          3
# 434          3
# 78           3
# 116          3
# 74           3
# Name: count, dtype: int64

# %% [markdown]
# Let's make an estimate of the cost in embedding, (0.02 per 1M tokens)

# %%
(final_df.issue_msg_n_tokens.sum() / 1000000) * 0.02
# Out:
# np.float64(0.17445496)

# %%
from utils import *

pandarallel.initialize(progress_bar=True, nb_workers=12)


def create_embedding(msg):
    try:
        return (
            client.embeddings.create(input=msg, model="text-embedding-3-large")
            .data[0]
            .embedding
        )
    except Exception as e:
        print(f"Error processing message: {msg}. Error: {e}")
        return None


final_df["issue_embedding"] = final_df.issue_msg.parallel_map(create_embedding)
# Out:
# INFO: Pandarallel will run on 12 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=367), Label(value='0 / 367'))), HB…

# %%
final_df.sample(5)
# Out:
#      cve_id cve_published cve_descriptions cve_metrics cve_references  \
# 4360    NaN           NaN              NaN         NaN            NaN
# 1974    NaN           NaN              NaN         NaN            NaN
# 1865    NaN           NaN              NaN         NaN            NaN
# 1407    NaN           NaN              NaN         NaN            NaN
# 4192    NaN           NaN              NaN         NaN            NaN
#
#      cve_configurations cve_primary_cwe cve_tags  \
# 4360                NaN          No_CWE      NaN
# 1974                NaN          No_CWE      NaN
# 1865                NaN          No_CWE      NaN
# 1407                NaN          No_CWE      NaN
# 4192                NaN          No_CWE      NaN
#
#                    issue_owner_repo  \
# 4360  (ros-navigation, navigation2)
# 1974    (axiomatic-systems, Bento4)
# 1865                   (gpac, gpac)
# 1407                   (gpac, gpac)
# 4192             (xuxueli, xxl-job)
#
#                                              issue_body  ...  \
# 4360  <!--\nFor general questions, please ask on Rob...  ...
# 1974  ## Environment \r\nUbuntu 22.04.3 LTS \r\n## C...  ...
# 1865  Extracting Mpeg-4 ASP stream fails using this ...  ...
# 1407  Thanks for reporting your issue. Please make s...  ...
# 4192  在云原生时代，随着容器化和弹性扩缩容的需求日益增长，我们发现当前 XxlJobExecuto...  ...
#
#      issue_comments_count    issue_created_at      issue_updated_at  \
# 4360                    1 2025-02-13 12:48:23  2025-02-13T17:46:50Z
# 1974                    0 2024-01-29 08:47:19  2024-02-17T17:22:16Z
# 1865                    1 2021-04-15 15:55:11  2021-04-16T17:09:57Z
# 1407                   14 2023-02-15 16:16:05  2023-06-26T12:01:07Z
# 4192                    0 2025-02-12 02:06:20  2025-02-12T02:24:50Z
#
#                                          issue_html_url issue_github_id  \
# 4360  https://github.com/ros-navigation/navigation2/...      2850946803
# 1974  https://github.com/axiomatic-systems/Bento4/is...      2104961150
# 1865           https://github.com/gpac/gpac/issues/1746       859021531
# 1407           https://github.com/gpac/gpac/issues/2399      1586143458
# 4192     https://github.com/xuxueli/xxl-job/issues/3654      2846991353
#
#      issue_number  label                                          issue_msg  \
# 4360         4918  False  This is a GitHub Issue\nrepo:navigation2\nowne...
# 1974          921  False  This is a GitHub Issue\nrepo:Bento4\nowner:axi...
# 1865         1746  False  This is a GitHub Issue\nrepo:gpac\nowner:gpac\...
# 1407         2399  False  This is a GitHub Issue\nrepo:gpac\nowner:gpac\...
# 4192         3654  False  This is a GitHub Issue\nrepo:xxl-job\nowner:xu...
#
#       issue_msg_n_tokens                                    issue_embedding
# 4360                3035  [-0.011350592598319054, 0.0021085701882839203,...
# 1974                7509  [-0.007885602302849293, 0.013403352349996567, ...
# 1865                2877  [-0.008600086905062199, 0.04178078845143318, -...
# 1407                1813  [-0.0005860996898263693, 0.028806578367948532,...
# 4192                1314  [-0.008026047609746456, -0.027120398357510567,...
#
# [5 rows x 22 columns]

# %%
print(len(final_df))
# Out:
# 4400

# %% [markdown]
# ## Create training ad testing split

# %%
import seaborn as sns
import matplotlib.pyplot as plt

k = 40
data = final_df[final_df["cve_primary_cwe"].apply(lambda x: x != None)][
    "cve_primary_cwe"
].value_counts(normalize=False)
data_df = data.head(40).reset_index()
data_df.columns = ["CWE", "Proportion"]
print("data len:\t", len(data))
display(data_df.head(10))
# Plotting
plt.figure(figsize=(10, 6))
sns.barplot(x="CWE", y="Proportion", hue="CWE", data=data_df, palette="viridis")

# Add labels and title
plt.xticks(rotation=45, ha="right")
plt.title(f"Proportion of top {k} CWEs")

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# data len:	 33
#       CWE  Proportion
# 0  No_CWE        3640
# 1     787         156
# 2     476         120
# 3      89          64
# 4     125          61
# 5     401          51
# 6     617          48
# 7     120          39
# 8     770          36
# 9     416          31

# %%
from sklearn.model_selection import train_test_split

final_df["stratify_label"] = (
    final_df["cve_primary_cwe"].astype(str) + "_" + final_df["issue_owner_repo"].astype(str)
)
X_train, X_test = train_test_split(
    final_df, test_size=0.4, random_state=99, stratify=final_df["cve_primary_cwe"]
)

X_train = X_train.drop(columns=["stratify_label"])
X_test = X_test.drop(columns=["stratify_label"])

# %%
print(len(X_train[~X_train['cve_primary_cwe'].isin(X_test['cve_primary_cwe'].values)]))
# Out:
# 0

# %%
X_train.label.mean(), X_test.label.mean()
# Out:
# (np.float64(0.17272727272727273), np.float64(0.17272727272727273))

# %%
from datasets import Dataset

# train
ds = Dataset.from_pandas(X_train, preserve_index=True)
ds.push_to_hub("Eathus/github-issues-vul-detection-cwe", split="train")

# test
ds = Dataset.from_pandas(X_test, preserve_index=True)
ds.push_to_hub("Eathus/github-issues-vul-detection-cwe", split="test")
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/3 [00:00<?, ?ba/s]
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# README.md:   0%|          | 0.00/7.18k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/Eathus/github-issues-vul-detection-cwe/commit/4b7715b03a33ecc1085635e575667f98923c32a9', commit_message='Upload dataset', commit_description='', oid='4b7715b03a33ecc1085635e575667f98923c32a9', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/Eathus/github-issues-vul-detection-cwe', endpoint='https://huggingface.co', repo_type='dataset', repo_id='Eathus/github-issues-vul-detection-cwe'), pr_revision=None, pr_num=None)

# %% [markdown]
# # Dataset analysis
# - t-SNE visualization

# %%
from datasets import load_dataset, concatenate_datasets

dataset_repo = "Eathus/github-issues-vul-detection-cwe"

train_ds = load_dataset(dataset_repo, split="train")
test_ds = load_dataset(dataset_repo, split="test")

combined_ds = concatenate_datasets([train_ds, test_ds])
final_df = combined_ds.to_pandas()
# Out:
# README.md:   0%|          | 0.00/7.28k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/52.5M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/34.9M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2640 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1760 [00:00<?, ? examples/s]

# %%
import numpy as np

X = final_df[["issue_embedding"]].values
labels = final_df["label"]

data = []
for i in X:
    data.append(i[0])
X = np.array(data)
X.shape
# Out:
# (4400, 3072)

# %%
from sklearn.manifold import TSNE
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("default")
tsne = TSNE(n_components=3, random_state=42)
X_tsne = tsne.fit_transform(X)


# Create a DataFrame for the t-SNE result
df_tsne = pd.DataFrame(X_tsne, columns=["Component 1", "Component 2", "Component 3"])
df_tsne["label"] = labels.values

# Plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection="3d")

for label in df_tsne["label"].unique():
    subset = df_tsne[df_tsne["label"] == label]
    ax.scatter(
        subset["Component 1"],
        subset["Component 2"],
        subset["Component 3"],
        label=label,
        s=7,
    )

ax.set_title("t-SNE plot")
ax.set_xlabel("Component 1")
ax.set_ylabel("Component 2")
ax.set_zlabel("Component 3")
ax.legend()
plt.savefig("tsne_plot.pdf", format="pdf", bbox_inches="tight")

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

# Plot the histograms

final_df[final_df.label]["issue_msg_n_tokens"].plot.hist(
    bins=100, alpha=0.5, label="Negative", color="red", density=True
)
final_df[~final_df.label]["issue_msg_n_tokens"].plot.hist(
    bins=100, alpha=0.5, label="Positive", color="blue", density=True
)
plt.legend()

plt.gca().yaxis.set_major_formatter(
    plt.FuncFormatter(lambda y, _: "{:.2f}%".format(y * 100))
)
plt.xlabel("Tokens")
plt.savefig("issue_dimension.png", bbox_inches="tight")
